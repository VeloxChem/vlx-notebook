# %% [markdown]
# # Jupyter notebooks
# Here, we explain how to visualize VeloxChem results in the Jupyter Notebook. The calculation can either be performed and visualized in the Jupyter Notebook or the results can be imported from a VeloxChem h5 file and then visualized.
# ## Molecular structure

# %% [markdown]
# In Jupyter notebook, a Veloxchem molecule object can be visualize using the show function. This is powevered by Py3DMol. The atom_indices and atom_labels options can be used.

# %% [markdown]
# **Directly from a Jupyter Notebook cell**

# %%
import veloxchem as vlx
molecule = vlx.Molecule.read_smiles('C1=CC=C(C=C1)C(=O)O')
molecule.show(atom_indices=True, atom_labels=True)
# Out:
# <div id="3dmolviewer_17479939006673539"  style="position: relative; width: 400px; height: 300px;">
#         <p id="3dmolwarning_17479939006673539" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdnjs.cloudflare.com/ajax/libs/3Dmol/2.4.2/3Dmol-min.js');
# }
#
# var viewer_17479939006673539 = null;
# var warn = document.getElementById("3dmolwarning_17479939006673539");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17479939006673539 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17479939006673539"),{backgroundColor:"white"});
# viewer_17479939006673539.zoomTo();
# 	viewer_17479939006673539.addModel("15\n\nC             -0.045431000000         1.985714000000        -1.068089000000\nC             -0.785397000000         0.832807000000        -1.340121000000\nC             -0.462986000000        -0.373231000000        -0.709821000000\nC              0.607616000000        -0.435910000000         0.202232000000\nC              1.345794000000         0.731857000000         0.468322000000\nC              1.018819000000         1.935160000000        -0.164965000000\nC              0.954661000000        -1.708145000000         0.872913000000\nO              0.294454000000        -2.755921000000         0.635933000000\nO              2.015464000000        -1.760191000000         1.773604000000\nH             -0.296655000000         2.918093000000        -1.557015000000\nH             -1.609932000000         0.873208000000        -2.040193000000\nH             -1.050525000000        -1.254224000000        -0.936128000000\nH              2.174869000000         0.716966000000         1.164537000000\nH              1.591497000000         2.829336000000         0.044996000000\nH              2.261507000000        -2.626101000000         2.238288000000\n");
# 	viewer_17479939006673539.setViewStyle({"style": "outline", "width": 0.05});
# 	viewer_17479939006673539.setStyle({"stick": {}, "sphere": {"scale": 0.25}});
# 	viewer_17479939006673539.addLabel("C1",{"position": {"x": -0.045431, "y": 1.985714, "z": -1.068089}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0});
# 	viewer_17479939006673539.addLabel("C2",{"position": {"x": -0.785397, "y": 0.832807, "z": -1.3401209999999997}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0});
# 	viewer_17479939006673539.addLabel("C3",{"position": {"x": -0.46298599999999995, "y": -0.3732309999999999, "z": -0.709821}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0});
# 	viewer_17479939006673539.addLabel("C4",{"position": {"x": 0.607616, "y": -0.43590999999999996, "z": 0.202232}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0});
# 	viewer_17479939006673539.addLabel("C5",{"position": {"x": 1.3457939999999997, "y": 0.7318569999999999, "z": 0.468322}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0});
# 	viewer_17479939006673539.addLabel("C6",{"position": {"x": 1.018819, "y": 1.93516, "z": -0.164965}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0});
# 	viewer_17479939006673539.addLabel("C7",{"position": {"x": 0.954661, "y": -1.708145, "z": 0.872913}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0});
# 	viewer_17479939006673539.addLabel("O8",{"position": {"x": 0.294454, "y": -2.7559209999999994, "z": 0.635933}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0});
# 	viewer_17479939006673539.addLabel("O9",{"position": {"x": 2.015464, "y": -1.760191, "z": 1.773604}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0});
# 	viewer_17479939006673539.addLabel("H10",{"position": {"x": -0.296655, "y": 2.918093, "z": -1.557015}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0});
# 	viewer_17479939006673539.addLabel("H11",{"position": {"x": -1.609932, "y": 0.8732079999999999, "z": -2.040193}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0});
# 	viewer_17479939006673539.addLabel("H12",{"position": {"x": -1.050525, "y": -1.254224, "z": -0.936128}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0});
# 	viewer_17479939006673539.addLabel("H13",{"position": {"x": 2.174869, "y": 0.716966, "z": 1.1645369999999997}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0});
# 	viewer_17479939006673539.addLabel("H14",{"position": {"x": 1.591497, "y": 2.8293359999999996, "z": 0.044996}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0});
# 	viewer_17479939006673539.addLabel("H15",{"position": {"x": 2.261507, "y": -2.626101, "z": 2.238288}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0});
# 	viewer_17479939006673539.zoomTo();
# viewer_17479939006673539.render();
# });
# </script>

# %% [markdown]
# **From an h5 file**

# %%
biph_dict = vlx.read_results("output_files/biphenyl-scf.h5", label="scf")
biph = vlx.Molecule.from_dict(biph_dict)
biph.show()
# Out:
# <div id="3dmolviewer_17478202928553178"  style="position: relative; width: 400px; height: 300px;">
#         <p id="3dmolwarning_17478202928553178" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdnjs.cloudflare.com/ajax/libs/3Dmol/2.4.2/3Dmol-min.js');
# }
#
# var viewer_17478202928553178 = null;
# var warn = document.getElementById("3dmolwarning_17478202928553178");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17478202928553178 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17478202928553178"),{backgroundColor:"white"});
# viewer_17478202928553178.zoomTo();
# 	viewer_17478202928553178.addModel("22\n\nC             -0.723400000000         0.000300000000        -0.000100000000\nC              0.723400000000        -0.000200000000        -0.000100000000\nC             -1.420600000000        -0.958600000000         0.734900000000\nC              1.420600000000         0.734800000000         0.958600000000\nC             -1.421000000000         0.958800000000        -0.735000000000\nC              1.421100000000        -0.735000000000        -0.958800000000\nC             -2.815400000000        -0.958800000000         0.735000000000\nC              2.815500000000         0.735100000000         0.958800000000\nC             -2.815900000000         0.958600000000        -0.734900000000\nC              2.815900000000        -0.734800000000        -0.958600000000\nC             -3.513200000000        -0.000200000000         0.000100000000\nC              3.513100000000         0.000100000000         0.000100000000\nH             -0.892300000000        -1.713000000000         1.313100000000\nH              0.892400000000         1.313200000000         1.713000000000\nH             -0.893100000000         1.713400000000        -1.313400000000\nH              0.893100000000        -1.313400000000        -1.713300000000\nH             -3.358400000000        -1.705400000000         1.307200000000\nH              3.358500000000         1.307400000000         1.705100000000\nH             -3.359300000000         1.704900000000        -1.307000000000\nH              3.359300000000        -1.306900000000        -1.705100000000\nH             -4.599200000000        -0.000400000000         0.000200000000\nH              4.599200000000         0.000300000000         0.000200000000\n");
# 	viewer_17478202928553178.setViewStyle({"style": "outline", "width": 0.05});
# 	viewer_17478202928553178.setStyle({"stick": {}, "sphere": {"scale": 0.25}});
# 	viewer_17478202928553178.zoomTo();
# viewer_17478202928553178.render();
# });
# </script>

# %% [markdown]
# ## Structure optimization

# %% [markdown]
# **Directly from a Jupyter Notebook cell**

# %%
molecule = vlx.Molecule.read_smiles('CCO')
basis = vlx.MolecularBasis.read(molecule, 'def2-svp')

scf_drv = vlx.ScfRestrictedDriver()
scf_drv.ostream.mute()
scf_drv.xcfun = 'b3lyp'
scf_drv.dispersion = 'd4'
results = scf_drv.compute(molecule, basis)

opt_drv = vlx.OptimizationDriver(scf_drv)
opt_results = opt_drv.compute(molecule, basis, results)
opt_drv.show_convergence(opt_results)
# Out:
# interactive(children=(IntSlider(value=7, description='step', max=7), Output()), _dom_classes=('widget-interact…

# %% [markdown]
# **From an h5 file**

# %%
opt_results = vlx.read_results("output_files/bithio-S0-opt.h5", label="opt")
opt_drv.show_convergence(opt_results)
# Out:
# interactive(children=(IntSlider(value=13, description='step', max=13), Output()), _dom_classes=('widget-intera…

# %% [markdown]
# ## Spectrum plotting

# %% [markdown]
# **Directly from a Jupyter Notebook cell**

# %%
molecule = vlx.Molecule.read_smiles('CCO')
basis = vlx.MolecularBasis.read(molecule, 'def2-svp')

scf_drv = vlx.ScfRestrictedDriver()
scf_drv.ostream.mute()
scf_drv.xcfun = 'b3lyp'
results = scf_drv.compute(molecule, basis)

rsp_drv = vlx.lreigensolver.LinearResponseEigenSolver()
rsp_drv.ostream.mute()
rsp_drv.nstates = 10
rsp_drv.nto = True
rsp_results = rsp_drv.compute(molecule, basis, results)
rsp_drv.plot(rsp_results)

# %% [markdown]
# **From an h5 file**

# %%
rsp_results = vlx.read_results("output_files/alanine-ecd.h5", label="rsp")
rsp_drv.plot_ecd(rsp_results)

# %% [markdown]
# ## Normal modes

# %% [markdown]
# **Directly from a Jupyter Notebook cell**

# %%
molecule = vlx.Molecule.read_smiles('CCO')
basis = vlx.MolecularBasis.read(molecule, 'def2-svp')

scf_drv = vlx.ScfRestrictedDriver()
scf_drv.ostream.mute()
scf_drv.xcfun = 'b3lyp'
results = scf_drv.compute(molecule, basis)

vib_drv = vlx.VibrationalAnalysis(scf_drv)
vib_drv.ostream.mute()
#vib_results = vib_drv.compute(molecule, basis)
#vib_drv.plot(vib_results)
#vib_drv.animate(vib_results, mode=14)

# %% [markdown]
# **From an h5 file**

# %%
vib_results = vlx.read_results("output_files/acro-raman.h5", label="vib")
vib_drv.plot_raman(vib_results)
vib_drv.animate(vib_results, mode=14)
# Out:
# <div id="3dmolviewer_17479939265456488"  style="position: relative; width: 400px; height: 300px;">
#         <p id="3dmolwarning_17479939265456488" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdnjs.cloudflare.com/ajax/libs/3Dmol/2.4.2/3Dmol-min.js');
# }
#
# var viewer_17479939265456488 = null;
# var warn = document.getElementById("3dmolwarning_17479939265456488");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17479939265456488 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17479939265456488"),{backgroundColor:"white"});
# viewer_17479939265456488.zoomTo();
# 	viewer_17479939265456488.addModel("8\n\nC -7.193469896121 -0.606513185315 0.051392766908 -0.022656 0.011084 -0.000477\nC -5.875615515175 -0.849065291590 0.042481132685 0.098351 0.000845 -0.002392\nC -4.889535693619 0.245221229217 -0.080553519627 -0.710805 0.042121 0.012896\nO -3.691300371749 0.086578691883 -0.094301147046 0.472209 -0.058277 -0.005804\nH -5.343436560117 1.269725354663 -0.163335974501 0.239578 0.372802 -0.039647\nH -7.932396644059 -1.406925824035 0.141819097832 0.006342 -0.016240 0.001332\nH -7.577705619481 0.416356866537 -0.032850542800 0.039520 0.024728 -0.003186\nH -5.465794362629 -1.861160187416 0.125149091897 -0.213034 -0.100319 0.014165","xyz",{"vibrate": {"frames": 15, "amplitude": 0.5}});
# 	viewer_17479939265456488.setViewStyle({"style": "outline", "width": 0.05});
# 	viewer_17479939265456488.setStyle({"stick": {}, "sphere": {"scale": 0.25}});
# 	viewer_17479939265456488.animate({"loop": "backAndForth"});
# 	viewer_17479939265456488.rotate(-90,"x");
# 	viewer_17479939265456488.zoomTo();
# viewer_17479939265456488.render();
# });
# </script>

# %%
vib_results = vlx.read_results("output_files/protein_vib.h5", label="vib")
vib_drv.animate(vib_results, mode=16)
# Out:
# <div id="3dmolviewer_17479939560285182"  style="position: relative; width: 400px; height: 300px;">
#         <p id="3dmolwarning_17479939560285182" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdnjs.cloudflare.com/ajax/libs/3Dmol/2.4.2/3Dmol-min.js');
# }
#
# var viewer_17479939560285182 = null;
# var warn = document.getElementById("3dmolwarning_17479939560285182");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17479939560285182 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17479939560285182"),{backgroundColor:"white"});
# viewer_17479939560285182.zoomTo();
# 	viewer_17479939560285182.addModel("1152\n\nN 37.390907610226 42.229960258833 29.293518853040 -0.000254 -0.000032 0.000447\nH 38.421796043157 42.108521425876 29.296298412194 -0.000241 0.000166 0.000659\nH 37.010927328065 41.608005409222 28.551192820654 0.000001 -0.000046 0.000334\nH 37.154491526313 43.204991839236 29.042355741512 -0.000347 -0.000055 0.000435\nC 36.792942916559 41.849520522973 30.608653088346 -0.000477 -0.000207 0.000299\nH 37.118814651658 42.569631170515 31.370251734005 -0.000759 -0.000194 0.000411\nC 35.253226813764 41.917033815787 30.448101833911 -0.000459 -0.000549 0.000004\nH 34.936748091820 41.071113866703 29.828472677207 -0.000168 -0.000781 0.000177\nH 35.027795337415 42.829955807903 29.878681232250 -0.000557 -0.000744 -0.000273\nC 34.348484337897 41.963995310821 31.700223153665 -0.000679 -0.000388 -0.000158\nH 34.498348124009 42.915097792074 32.226104352057 -0.000987 -0.000170 -0.000456\nC 32.882903744708 41.882821467056