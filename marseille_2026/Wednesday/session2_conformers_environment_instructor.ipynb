# %% [markdown]
# # Session 2 — Conformational Search, QM/MM & Environment
#
# **eChem School — Marseille 2026**
#
# This session covers three related topics:
#
# 1. **Systematic conformational search** — use VeloxChem's `ConformerGenerator` class to exhaustively enumerate and minimize conformers.
# 2. **Extract conformers from an MD simulation** — Perform a MD simulation at high temperature and optimize snaphots along the trajectory to find conformers.
# 3. **QM/MM and environment models** — implicit solvation (CPCM, SMD) and explicit polarizable embedding (PE) with VeloxChem.

# %% [markdown]
# # Part 1 — Systematic Conformational Search with VeloxChem
#
# For larger flexible molecules (e.g. drug candidates), MD is not the most efficient way to sample conformational space. A **systematic search** rotates all rotatable bonds through a grid of angles, generating all possible arrangements, and then minimizes each one.
#
# VeloxChem provides the `ConformerGenerator` class, which:
# 1. Enumerates all combinations of rotatable-bond torsion angles.
# 2. Minimizes each conformer with an MM force field (optionally with RESP charges or an implicit solvent).
# 3. Filters duplicate structures by RMSD.
#
# We demonstrate with **L-alanine** — a flexible molecule with multiple rotatable bonds.

# %%
import veloxchem as vlx

# Penicillin G
molecule = vlx.Molecule.read_smiles(
    'C[C@@H](C(=O)O)N'
)
molecule.show(atom_indices=True)
# Out:
# <div id="3dmolviewer_17791769616397374"  style="position: relative; width: 400px; height: 300px;">
#         <p id="3dmolwarning_17791769616397374" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdn.jsdelivr.net/npm/3dmol@2.5.4/build/3Dmol-min.js');
# }
#
# var viewer_17791769616397374 = null;
# var warn = document.getElementById("3dmolwarning_17791769616397374");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17791769616397374 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17791769616397374"),{backgroundColor:"white"});
# viewer_17791769616397374.zoomTo();
# 	viewer_17791769616397374.addModel("13\n\nC             -0.623167000000         1.112730000000        -0.124732000000\nC              0.419075000000         0.869532000000         0.973239000000\nC              0.377776000000        -0.560822000000         1.427298000000\nO             -0.013380000000        -0.842125000000         2.591835000000\nO              0.756552000000        -1.580768000000         0.558718000000\nN              1.766326000000         1.203137000000         0.507591000000\nH             -0.416998000000         0.477287000000        -1.012814000000\nH             -1.640277000000         0.878503000000         0.256402000000\nH             -0.604578000000         2.178711000000        -0.436095000000\nH              0.172195000000         1.527043000000         1.837098000000\nH              0.727528000000        -2.550078000000         0.851476000000\nH              1.963711000000         0.696116000000        -0.386533000000\nH              1.802019000000         2.227189000000         0.296624000000\n");
# 	viewer_17791769616397374.addLabel("1",{"position": {"x": -0.623167, "y": 1.11273, "z": -0.124732}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0, "fontSize": 16});
# 	viewer_17791769616397374.addLabel("2",{"position": {"x": 0.419075, "y": 0.8695319999999999, "z": 0.973239}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0, "fontSize": 16});
# 	viewer_17791769616397374.addLabel("3",{"position": {"x": 0.377776, "y": -0.560822, "z": 1.427298}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0, "fontSize": 16});
# 	viewer_17791769616397374.addLabel("4",{"position": {"x": -0.01338, "y": -0.8421249999999999, "z": 2.591835}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0, "fontSize": 16});
# 	viewer_17791769616397374.addLabel("5",{"position": {"x": 0.756552, "y": -1.5807679999999997, "z": 0.558718}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0, "fontSize": 16});
# 	viewer_17791769616397374.addLabel("6",{"position": {"x": 1.7663259999999998, "y": 1.203137, "z": 0.507591}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0, "fontSize": 16});
# 	viewer_17791769616397374.addLabel("7",{"position": {"x": -0.416998, "y": 0.47728699999999996, "z": -1.012814}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0, "fontSize": 16});
# 	viewer_17791769616397374.addLabel("8",{"position": {"x": -1.640277, "y": 0.878503, "z": 0.256402}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0, "fontSize": 16});
# 	viewer_17791769616397374.addLabel("9",{"position": {"x": -0.604578, "y": 2.178711, "z": -0.436095}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0, "fontSize": 16});
# 	viewer_17791769616397374.addLabel("10",{"position": {"x": 0.172195, "y": 1.5270429999999997, "z": 1.837098}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0, "fontSize": 16});
# 	viewer_17791769616397374.addLabel("11",{"position": {"x": 0.727528, "y": -2.550078, "z": 0.851476}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0, "fontSize": 16});
# 	viewer_17791769616397374.addLabel("12",{"position": {"x": 1.963711, "y": 0.696116, "z": -0.386533}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0, "fontSize": 16});
# 	viewer_17791769616397374.addLabel("13",{"position": {"x": 1.802019, "y": 2.227189, "z": 0.29662399999999994}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0, "fontSize": 16});
# 	viewer_17791769616397374.setViewStyle({"style": "outline", "width": 0.05});
# 	viewer_17791769616397374.setStyle({"stick": {}, "sphere": {"scale": 0.25}});
# 	viewer_17791769616397374.zoomTo();
# viewer_17791769616397374.render();
# });
# </script>

# %% [markdown]
# ## 1.1 Basic conformer generation

# %%
conf = vlx.ConformerGenerator()
conformers_dict = conf.generate(molecule)

print(f'{len(conformers_dict["molecules"])} conformers found')
conf.show_global_minimum()
# Out:
#
#                                             Self Consistent Field Driver Setup
#                                            ====================================
#
#                    Wave Function Model             : Spin-Restricted Hartree-Fock
#                    Initial Guess Model             : Superposition of Atomic Densities
#                    Convergence Accelerator         : Two Level Direct Inversion of Iterative Subspace
#                    Max. Number of Iterations       : 50
#                    Max. Number of Error Vectors    : 10
#                    Convergence Threshold           : 1.0e-06
#                    ERI Screening Threshold         : 1.0e-12
#                    Linear Dependence Threshold     : 1.0e-06
#
# * Info * Starting Reduced Basis SCF calculation...
# * Info * ...done. SCF energy in reduced basis set: -321.690713571821 a.u. Time: 0.85 sec.
#
#
#                Iter. | Hartree-Fock Energy | Energy Change | Gradient Norm | Max. Gradient | Density Change
#                --------------------------------------------------------------------------------------------
#                   1      -321.823724824351    0.0000000000      0.18659466      0.00981540      0.00000000
#                   2      -321.827743093835   -0.0040182695      0.07227319      0.00687326      0.08429416
#                   3      -321.828226761987   -0.0004836682      0.02577071      0.00136448      0.02242398
#                   4      -321.828301787462   -0.0000750255      0.00661930      0.00042637      0.00772491
#                   5      -321.828308962360   -0.0000071749      0.00211529      0.00017443      0.00376917
#                   6      -321.828309986132   -0.0000010238      0.00076126      0.00004466      0.00152266
#                   7      -321.828310127148   -0.0000001410      0.00024971      0.00001846      0.00056746
#                   8      -321.828310153520   -0.0000000264      0.00008229      0.00000489      0.00028284
#                   9      -321.828310156815   -0.0000000033      0.00003286      0.00000252      0.00008793
#                  10      -321.828310157396   -0.0000000006      0.00001247      0.00000109      0.00003273
#                  11      -321.828310157486   -0.0000000001      0.00000475      0.00000043      0.00001303
#                  12      -321.828310157500   -0.0000000000      0.00000169      0.00000014      0.00000564
#                  13      -321.828310157502   -0.0000000000      0.00000063      0.00000004      0.00000200
#
#                *** SCF converged in 13 iterations. Time: 3.12 sec.
#
#                Spin-Restricted Hartree-Fock:
#                -----------------------------
#                Total Energy                       :     -321.8283101575 a.u.
#                Electronic Energy                  :     -567.0458250824 a.u.
#                Nuclear Repulsion Energy           :      245.2175149249 a.u.
#                ------------------------------------
#                Gradient Norm                      :        0.0000006312 a.u.
#
#
#                Ground State Information
#                ------------------------
#                Charge of Molecule            :  0.0
#                Multiplicity (2S+1)           :  1
#                Magnetic Quantum Number (M_S) :  0.0
#
#
#                                                 RESP Charges Driver Setup
#                                                ===========================
#
#                                          Number of Conformers         :  1
#                                          Number of Layers             :  4
#                                          Points per Square Angstrom   :  1.0
#                                          Total Number of Grid Points  :  713
#
#
#                                                      First Stage Fit
#                                                     -----------------
#
#                                          Restraint Strength           :  0.0005
#                                          Restrained Hydrogens         :  No
#                                          Max. Number of Iterations    :  50
#                                          Convergence Threshold (a.u.) :  1e-06
#
#                                       *** Charge fitting converged in 12 iterations.
#
#                                         No. | Atom |  Constraints | Charges (a.u.)
#                                        --------------------------------------------
#                                           1     C                     -0.358549
#                                           2     C                      0.290275
#                                           3     C                      0.753181
#                                           4     O                     -0.614892
#                                           5     O                     -0.665113
#                                           6     N                     -0.985470
#                                           7     H                      0.098656
#                                           8     H                      0.076981
#                                           9     H                      0.104025
#                                          10     H                      0.074747
#                                          11     H                      0.473470
#                                          12     H                      0.370232
#                                          13     H                      0.382457
#                                        --------------------------------------------
#                                                Total Charge  :  0.000000
#
#                                                        Fit Quality
#                                                       -------------
#                                        Relative Root-Mean-Square Error  :  0.091482
#
#
#                                                      Second Stage Fit
#                                                     ------------------
#
#                                          Restraint Strength           :  0.001
#                                          Restrained Hydrogens         :  No
#                                          Max. Number of Iterations    :  50
#                                          Convergence Threshold (a.u.) :  1e-06
#
#                                       *** Charge fitting converged in 4 iterations.
#
#                                     No. | Atom | Frozen | Constraints | Charges (a.u.)
#                                    ----------------------------------------------------
#                                       1     C       No                    -0.352933
#                                       2     C      Yes                     0.290275
#                                       3     C      Yes                     0.753181
#                                       4     O      Yes                    -0.614892
#                                       5     O      Yes                    -0.665113
#                                       6     N      Yes                    -0.985470
#                                       7     H       No                     0.091349
#                                       8     H       No         7           0.091349
#                                       9     H       No         8           0.091349
#                                      10     H      Yes                     0.074747
#                                      11     H      Yes                     0.473470
#                                      12     H      Yes                     0.370232
#                                      13     H      Yes                     0.382457
#                                    ----------------------------------------------------
#                                                Total Charge  :  0.000000
#
#                                                        Fit Quality
#                                                       -------------
#                                        Relative Root-Mean-Square Error  :  0.098629
#
#                                        Reference:
#                                        J. Phys. Chem. 1993, 97, 10269-10280.
#
# * Info * 18 conformers will be generated.
# * Info * 18 conformers generated in 0.01 sec
# * Info * Energy minimization of 18 conformers took 0.10 sec
# * Info * Global minimum energy: 150.258 kJ/mol
# * Info * 8 conformers remain after removal of duplicate conformers.
# * Info * Total time spent in generating conformers: 4.26 sec
# 8 conformers found
# Global minimum conformer with energy 150.258 kJ/mol
# <div id="3dmolviewer_17791769659040353"  style="position: relative; width: 400px; height: 300px;">
#         <p id="3dmolwarning_17791769659040353" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdn.jsdelivr.net/npm/3dmol@2.5.4/build/3Dmol-min.js');
# }
#
# var viewer_17791769659040353 = null;
# var warn = document.getElementById("3dmolwarning_17791769659040353");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17791769659040353 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17791769659040353"),{backgroundColor:"white"});
# viewer_17791769659040353.zoomTo();
# 	viewer_17791769659040353.addModel("13\n\nC             -0.641685789486         1.180365330022        -0.096451289680\nC              0.452052516787         0.802918064876         0.915190820958\nC              0.382190773057        -0.670126410174         1.405930037390\nO             -0.713479149618        -1.267218803143         1.570048776990\nO              1.565331430114        -1.365894106586         1.580279268864\nN              1.779246064619         1.130865819605         0.325458922926\nH             -0.564231206922         0.567027416958        -1.020238191454\nH             -1.644952721929         1.004483655245         0.350551748835\nH             -0.573844082863         2.255035746751        -0.367347251436\nH              0.307426289742         1.434459330117         1.822318551637\nH              2.387732071366        -0.813324218478         1.375136192671\nH              1.865083680383         0.657893646546        -0.609910028767\nH              1.808608235787         2.163615480741         0.140840430571\n");
# 	viewer_17791769659040353.setViewStyle({"style": "outline", "width": 0.05});
# 	viewer_17791769659040353.setStyle({"stick": {}, "sphere": {"scale": 0.25}});
# 	viewer_17791769659040353.zoomTo();
# viewer_17791769659040353.render();
# });
# </script>

# %%
# Show the three lowest-energy conformers
conf.show_conformers(number=3, atom_indices=True)
# Out:
# Conformer 1 with energy 150.258 kJ/mol
# <div id="3dmolviewer_1779176965907619"  style="position: relative; width: 400px; height: 300px;">
#         <p id="3dmolwarning_1779176965907619" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdn.jsdelivr.net/npm/3dmol@2.5.4/build/3Dmol-min.js');
# }
#
# var viewer_1779176965907619 = null;
# var warn = document.getElementById("3dmolwarning_1779176965907619");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_1779176965907619 = $3Dmol.createViewer(document.getElementById("3dmolviewer_1779176965907619"),{backgroundColor:"white"});
# viewer_1779176965907619.zoomTo();
# 	viewer_1779176965907619.addModel("13\n\nC             -0.641685789486         1.180365330022        -0.096451289680\nC              0.452052516787         0.802918064876         0.915190820958\nC              0.382190773057        -0.670126410174         1.405930037390\nO             -0.713479149618        -1.267218803143         1.570048776990\nO              1.565331430114        -1.365894106586         1.580279268864\nN              1.779246064619         1.130865819605         0.325458922926\nH             -0.564231206922         0.567027416958        -1.020238191454\nH             -1.644952721929         1.004483655245         0.350551748835\nH             -0.573844082863         2.255035746751        -0.367347251436\nH              0.307426289742         1.434459330117         1.822318551637\nH              2.387732071366        -0.813324218478         1.375136192671\nH              1.865083680383         0.657893646546        -0.609910028767\nH              1.808608235787         2.163615480741         0.140840430571\n");
# 	viewer_1779176965907619.addLabel("1",{"position": {"x": -0.6416857894857174, "y": 1.1803653300218342, "z": -0.09645128967963684}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0, "fontSize": 16});
# 	viewer_1779176965907619.addLabel
setStyle({"stick": {}, "sphere": {"scale": 0.25}});
# 	viewer_17791769659090712.zoomTo();
# viewer_17791769659090712.render();
# });
# </script>

# %% [markdown]
# ## 2.2 With RESP partial charges
#
# By default the generator uses GAFF charges. We can improve accuracy by providing RESP charges computed at HF/6-31G*.

# %%
basis = vlx.MolecularBasis.read(molecule, '6-31g*')
resp  = vlx.RespChargesDriver()
resp.ostream.mute()
partial_charges = resp.compute(molecule, basis)

conf_resp = vlx.ConformerGenerator()
conf_resp.partial_charges = partial_charges
conformers_dict_resp = conf_resp.generate(molecule)

conf_resp.show_global_minimum(atom_indices=True)
# Out:
# * Info * 18 conformers will be generated.
# * Info * 18 conformers generated in 0.02 sec
# * Info * Energy minimization of 18 conformers took 0.12 sec
# * Info * Global minimum energy: 150.258 kJ/mol
# * Info * 8 conformers remain after removal of duplicate conformers.
# * Info * Total time spent in generating conformers: 0.17 sec
# Global minimum conformer with energy 150.258 kJ/mol
# <div id="3dmolviewer_17791769699955034"  style="position: relative; width: 400px; height: 300px;">
#         <p id="3dmolwarning_17791769699955034" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdn.jsdelivr.net/npm/3dmol@2.5.4/build/3Dmol-min.js');
# }
#
# var viewer_17791769699955034 = null;
# var warn = document.getElementById("3dmolwarning_17791769699955034");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17791769699955034 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17791769699955034"),{backgroundColor:"white"});
# viewer_17791769699955034.zoomTo();
# 	viewer_17791769699955034.addModel("13\n\nC             -0.641685789486         1.180365330022        -0.096451289680\nC              0.452052516787         0.802918064876         0.915190820958\nC              0.382190773057        -0.670126410174         1.405930037390\nO             -0.713479149618        -1.267218803143         1.570048776990\nO              1.565331430114        -1.365894106586         1.580279268864\nN              1.779246064619         1.130865819605         0.325458922926\nH             -0.564231206922         0.567027416958        -1.020238191454\nH             -1.644952721929         1.004483655245         0.350551748835\nH             -0.573844082863         2.255035746751        -0.367347251436\nH              0.307426289742         1.434459330117         1.822318551637\nH              2.387732071366        -0.813324218478         1.375136192671\nH              1.865083680383         0.657893646546        -0.609910028767\nH              1.808608235787         2.163615480741         0.140840430571\n");
# 	viewer_17791769699955034.addLabel("1",{"position": {"x": -0.6416857894857174, "y": 1.1803653300218342, "z": -0.09645128967963684}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0, "fontSize": 16});
# 	viewer_17791769699955034.addLabel("2",{"position": {"x": 0.45205251678711766, "y": 0.8029180648761485, "z": 0.9151908209582642}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0, "fontSize": 16});
# 	viewer_17791769699955034.addLabel("3",{"position": {"x": 0.38219077305719495, "y": -0.6701264101741953, "z": 1.405930037389964}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0, "fontSize": 16});
# 	viewer_17791769699955034.addLabel("4",{"position": {"x": -0.7134791496182201, "y": -1.2672188031428928, "z": 1.5700487769899885}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0, "fontSize": 16});
# 	viewer_17791769699955034.addLabel("5",{"position": {"x": 1.5653314301142927, "y": -1.365894106585973, "z": 1.5802792688636222}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0, "fontSize": 16});
# 	viewer_17791769699955034.addLabel("6",{"position": {"x": 1.7792460646192683, "y": 1.1308658196053276, "z": 0.3254589229264904}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0, "fontSize": 16});
# 	viewer_17791769699955034.addLabel("7",{"position": {"x": -0.5642312069217774, "y": 0.5670274169579054, "z": -1.02023819145412}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0, "fontSize": 16});
# 	viewer_17791769699955034.addLabel("8",{"position": {"x": -1.644952721928914, "y": 1.0044836552448895, "z": 0.3505517488350202}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0, "fontSize": 16});
# 	viewer_17791769699955034.addLabel("9",{"position": {"x": -0.5738440828633374, "y": 2.2550357467511644, "z": -0.36734725143622515}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0, "fontSize": 16});
# 	viewer_17791769699955034.addLabel("10",{"position": {"x": 0.30742628974216824, "y": 1.434459330117457, "z": 1.8223185516374891}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0, "fontSize": 16});
# 	viewer_17791769699955034.addLabel("11",{"position": {"x": 2.3877320713658854, "y": -0.8133242184777028, "z": 1.3751361926710128}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0, "fontSize": 16});
# 	viewer_17791769699955034.addLabel("12",{"position": {"x": 1.865083680383168, "y": 0.6578936465458034, "z": -0.6099100287665373}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0, "fontSize": 16});
# 	viewer_17791769699955034.addLabel("13",{"position": {"x": 1.808608235786728, "y": 2.163615480741455, "z": 0.14084043057071202}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0, "fontSize": 16});
# 	viewer_17791769699955034.setViewStyle({"style": "outline", "width": 0.05});
# 	viewer_17791769699955034.setStyle({"stick": {}, "sphere": {"scale": 0.25}});
# 	viewer_17791769699955034.zoomTo();
# viewer_17791769699955034.render();
# });
# </script>

# %% [markdown]
# ## 2.3 With implicit solvent
#
# The implicit OBC2 solvent model (a generalised Born variant) shifts conformer stabilities towards more polar geometries.

# %%
conf_solv = vlx.ConformerGenerator()
conf_solv.ostream.mute()
conf_solv.show_available_implicit_solvent_models()

conf_solv.implicit_solvent_model = 'obc2'
conformers_dict_solv = conf_solv.generate(molecule)
conf_solv.show_global_minimum(atom_indices=True)
# Out:
# Available implicit solvent files:
# gbn2.xml
# hct.xml
# obc1.xml
# obc2.xml
# gbn.xml
#
#                                             Self Consistent Field Driver Setup
#                                            ====================================
#
#                    Wave Function Model             : Spin-Restricted Hartree-Fock
#                    Initial Guess Model             : Superposition of Atomic Densities
#                    Convergence Accelerator         : Two Level Direct Inversion of Iterative Subspace
#                    Max. Number of Iterations       : 50
#                    Max. Number of Error Vectors    : 10
#                    Convergence Threshold           : 1.0e-06
#                    ERI Screening Threshold         : 1.0e-12
#                    Linear Dependence Threshold     : 1.0e-06
#
# * Info * Starting Reduced Basis SCF calculation...
# * Info * ...done. SCF energy in reduced basis set: -321.690713571820 a.u. Time: 0.75 sec.
#
#
#                Iter. | Hartree-Fock Energy | Energy Change | Gradient Norm | Max. Gradient | Density Change
#                --------------------------------------------------------------------------------------------
#                   1      -321.823724824351    0.0000000000      0.18659466      0.00981540      0.00000000
#                   2      -321.827743093835   -0.0040182695      0.07227319      0.00687326      0.08429416
#                   3      -321.828226761987   -0.0004836682      0.02577071      0.00136448      0.02242398
#                   4      -321.828301787462   -0.0000750255      0.00661930      0.00042637      0.00772491
#                   5      -321.828308962360   -0.0000071749      0.00211529      0.00017443      0.00376917
#                   6      -321.828309986132   -0.0000010238      0.00076126      0.00004466      0.00152266
#                   7      -321.828310127149   -0.0000001410      0.00024971      0.00001846      0.00056746
#                   8      -321.828310153520   -0.0000000264      0.00008229      0.00000489      0.00028284
#                   9      -321.828310156814   -0.0000000033      0.00003286      0.00000252      0.00008793
#                  10      -321.828310157396   -0.0000000006      0.00001247      0.00000109      0.00003273
#                  11      -321.828310157486   -0.0000000001      0.00000475      0.00000043      0.00001303
#                  12      -321.828310157500   -0.0000000000      0.00000169      0.00000014      0.00000564
#                  13      -321.828310157502   -0.0000000000      0.00000063      0.00000004      0.00000200
#
#                *** SCF converged in 13 iterations. Time: 3.15 sec.
#
#                Spin-Restricted Hartree-Fock:
#                -----------------------------
#                Total Energy                       :     -321.8283101575 a.u.
#                Electronic Energy                  :     -567.0458250824 a.u.
#                Nuclear Repulsion Energy           :      245.2175149249 a.u.
#                ------------------------------------
#                Gradient Norm                      :        0.0000006312 a.u.
#
#
#                Ground State Information
#                ------------------------
#                Charge of Molecule            :  0.0
#                Multiplicity (2S+1)           :  1
#                Magnetic Quantum Number (M_S) :  0.0
#
#
#                                                 RESP Charges Driver Setup
#                                                ===========================
#
#                                          Number of Conformers         :  1
#                                          Number of Layers             :  4
#                                          Points per Square Angstrom   :  1.0
#                                          Total Number of Grid Points  :  713
#
#
#                                                      First Stage Fit
#                                                     -----------------
#
#                                          Restraint Strength           :  0.0005
#                                          Restrained Hydrogens         :  No
#                                          Max. Number of Iterations    :  50
#                                          Convergence Threshold (a.u.) :  1e-06
#
#                                       *** Charge fitting converged in 12 iterations.
#
#                                         No. | Atom |  Constraints | Charges (a.u.)
#                                        --------------------------------------------
#                                           1     C                     -0.358549
#                                           2     C                      0.290275
#                                           3     C                      0.753181
#                                           4     O                     -0.614892
#                                           5     O                     -0.665113
#                                           6     N                     -0.985470
#                                           7     H                      0.098656
#                                           8     H                      0.076981
#                                           9     H                      0.104025
#                                          10     H                      0.074747
#                                          11     H                      0.473470
#                                          12     H                      0.370232
#                                          13     H                      0.382457
#                                        --------------------------------------------
#                                                Total Charge  :  0.000000
#
#                                                        Fit Quality
#                                                       -------------
#                                        Relative Root-Mean-Square Error  :  0.091482
#
#
#                                                      Second Stage Fit
#                                                     ------------------
#
#                                          Restraint Strength           :  0.001
#                                          Restrained Hydrogens         :  No
#                                          Max. Number of Iterations    :  50
#                                          Convergence Threshold (a.u.) :  1e-06
#
#                                       *** Charge fitting converged in 4 iterations.
#
#                                     No. | Atom | Frozen | Constraints | Charges (a.u.)
#                                    ----------------------------------------------------
#                                       1     C       No                    -0.352933
#                                       2     C      Yes                     0.290275
#                                       3     C      Yes                     0.753181
#                                       4     O      Yes                    -0.614892
#                                       5     O      Yes                    -0.665113
#                                       6     N      Yes                    -0.985470
#                                       7     H       No                     0.091349
#                                       8     H       No         7           0.091349
#                                       9     H       No         8           0.091349
#                                      10     H      Yes                     0.074747
#                                      11     H      Yes                     0.473470
#                                      12     H      Yes                     0.370232
#                                      13     H      Yes                     0.382457
#                                    ----------------------------------------------------
#                                                Total Charge  :  0.000000
#
#                                                        Fit Quality
#                                                       -------------
#                                        Relative Root-Mean-Square Error  :  0.098629
#
#                                        Reference:
#                                        J. Phys. Chem. 1993, 97, 10269-10280.
#
# Global minimum conformer with energy 75.125 kJ/mol
# <div id="3dmolviewer_17791769742897666"  style="position: relative; width: 400px; height: 300px;">
#         <p id="3dmolwarning_17791769742897666" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdn.jsdelivr.net/npm/3dmol@2.5.4/build/3Dmol-min.js');
# }
#
# var viewer_17791769742897666 = null;
# var warn = document.getElementById("3dmolwarning_17791769742897666");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17791769742897666 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17791769742897666"),{backgroundColor:"white"});
# viewer_17791769742897666.zoomTo();
# 	viewer_17791769742897666.addModel("13\n\nC             -0.446095601388         1.026576440012        -0.422970523475\nC              0.092255183340         0.899325091536         1.014021281112\nC             -0.073156735262        -0.532747338049         1.630286148885\nO             -1.019344164006        -1.308584526189         1.298650688275\nO              0.878868927201        -1.028612932708         2.512754024659\nN              1.505008772828         1.380621893364         1.035245876158\nH              0.100682931547         0.354753680196        -1.119874364008\nH             -1.525078415556         0.760532572363        -0.451574204591\nH             -0.348454398940         2.072825178278        -0.783440948481\nH             -0.515692519914         1.578933553444         1.656479070005\nH              1.647250623711        -0.385548585343         2.702993774904\nH              2.070834885878         0.817773677834         0.342174209730\nH              1.513810758791         2.375242638246         0.679726838108\n");
# 	viewer_17791769742897666.addLabel("1",{"position": {"x": -0.44609560138808857, "y": 1.0265764400117219, "z": -0.42297052347539327}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0, "fontSize": 16});
# 	viewer_17791769742897666.addLabel("2",{"position": {"x": 0.09225518334017295, "y": 0.8993250915358221, "z": 1.014021281112075}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0, "fontSize": 16});
# 	viewer_17791769742897666.addLabel("3",{"position": {"x": -0.07315673526193521, "y": -0.5327473380487372, "z": 1.630286148885346}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0, "fontSize": 16});
# 	viewer_17791769742897666.addLabel("4",{"position": {"x": -1.0193441640058563, "y": -1.308584526189251, "z": 1.298650688274562}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0, "fontSize": 16});
# 	viewer_17791769742897666.addLabel("5",{"position": {"x": 0.8788689272014271, "y": -1.0286129327075042, "z": 2.512754024658896}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0, "fontSize": 16});
# 	viewer_17791769742897666.addLabel("6",{"position": {"x": 1.5050087728278674, "y": 1.3806218933637262, "z": 1.0352458761584054}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0, "fontSize": 16});
# 	viewer_17791769742897666.addLabel("7",{"position": {"x": 0.100682931546625, "y": 0.3547536801963392, "z": -1.1198743640082465}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0, "fontSize": 16});
# 	viewer_17791769742897666.addLabel("8",{"position": {"x": -1.5250784155562513, "y": 0.7605325723630609, "z": -0.4515742045911757}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0, "fontSize": 16});
# 	viewer_17791769742897666.addLabel("9",{"position": {"x": -0.34845439893953695, "y": 2.072825178277726, "z": -0.7834409484809269}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0, "fontSize": 16});
# 	viewer_17791769742897666.addLabel("10",{"position": {"x": -0.5156925199142235, "y": 1.5789335534435287, "z": 1.656479070005012}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0, "fontSize": 16});
# 	viewer_17791769742897666.addLabel("11",{"position": {"x": 1.6472506237110227, "y": -0.3855485853430278, "z": 2.7029937749040283}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0, "fontSize": 16});
# 	viewer_17791769742897666.addLabel("12",{"position": {"x": 2.0708348858782184, "y": 0.8177736778335083, "z": 0.34217420972969864}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0, "fontSize": 16});
# 	viewer_17791769742897666.addLabel("13",{"position": {"x": 1.5138107587910756, "y": 2.37524263824602, "z": 0.6797268381081598}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0, "fontSize": 16});
# 	viewer_17791769742897666.setViewStyle({"style": "outline", "width": 0.05});
# 	viewer_17791769742897666.setStyle({"stick": {}, "sphere": {"scale": 0.25}});
# 	viewer_17791769742897666.zoomTo();
# viewer_17791769742897666.render();
# });
# </script>

# %% [markdown]
# ## 2.4 Conformer extraction from high-temperature MD
#
# For very flexible polymers, the systematic grid explodes combinatorially. A better approach is to run high-temperature MD and sample snapshots. VeloxChem's `OpenMMDynamics.conformational_sampling` does this automatically: it runs NVT MD at an elevated temperature (e.g. 1000 K), extracts snapshots, minimises each one, and optionally deduplicates identical structures.

# %%
# Load a larger molecule for the MD-based conformer search
penicilin = vlx.Molecule.read_smiles('CC1([C@@H](N2[C@H](S1)[C@@H](C2=O)NC(=O)CC3=CC=CC=C3)C(=O)O)C')
penicilin.show()
# Out:
# <div id="3dmolviewer_17791769743211622"  style="position: relative; width: 400px; height: 300px;">
#         <p id="3dmolwarning_17791769743211622" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdn.jsdelivr.net/npm/3dmol@2.5.4/build/3Dmol-min.js');
# }
#
# var viewer_17791769743211622 = null;
# var warn = document.getElementById("3dmolwarning_17791769743211622");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17791769743211622 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17791769743211622"),{backgroundColor:"white"});
# viewer_17791769743211622.zoomTo();
# 	viewer_17791769743211622.addModel("41\n\nC             -0.443549000000         2.001105000000         0.299384000000\nC             -1.216085000000         1.442869000000         1.508186000000\nC             -2.675854000000         1.089853000000         1.074063000000\nN             -2.606600000000        -0.306676000000         0.732561000000\nC             -1.667344000000        -1.204814000000         1.332588000000\nS             -0.367364000000        -0.122265000000         2.036829000000\nC             -1.406190000000        -1.907259000000         0.095260000000\nC             -2.432962000000        -1.029609000000        -0.548858000000\nO             -2.901292000000        -0.909035000000        -1.710385000000\nN             -0.069580000000        -1.687670000000        -0.462946000000\nC              1.071246000000        -2.419394000000         0.003732000000\nO              0.951362000000        -3.254961000000         0.940606000000\nC              2.406691000000        -2.222050000000        -0.644764000000\nC              2.486444000000        -3.021137000000        -1.915511000000\nC              2.879005000000        -4.369928000000        -1.879092000000\nC              2.919449000000        -5.123381000000        -3.056119000000\nC              2.560564000000        -4.540020000000        -4.274034000000\nC              2.157576000000        -3.202399000000        -4.316935000000\nC              2.115937000000        -2.444944000000        -3.142475000000\nC             -3.706856000000         1.273183000000         2.155913000000\nO             -4.501406000000         2.250100000000         2.106750000000\nO             -3.762060000000         0.390651000000         3.231159000000\nC             -1.138390000000         2.466735000000         2.657193000000\nH             -0.879575000000         2.969325000000        -0.028705000000\nH             -0.485013000000         1.292823000000        -0.554666000000\nH              0.624130000000         2.166769000000         0.559163000000\nH             -2.990423000000         1.672951000000         0.179214000000\nH             -2.158563000000        -1.840087000000         2.102229000000\nH             -1.708405000000        -2.977192000000         0.096949000000\nH              0.050689000000        -1.042050000000        -1.276238000000\nH              2.559618000000        -1.141483000000        -0.855534000000\nH              3.215090000000        -2.533441000000         0.052268000000\nH              3.150331000000        -4.836875000000        -0.940024000000\nH              3.225755000000        -6.160525000000        -3.023422000000\nH              2.590863000000        -5.124856000000        -5.184220000000\nH              1.873602000000        -2.753460000000        -5.259966000000\nH              1.793829000000        -1.412088000000        -3.189456000000\nH             -4.443375000000         0.513378000000         3.970836000000\nH             -0.080909000000         2.734333000000         2.868901000000\nH             -1.568488000000         2.046943000000         3.591096000000\nH             -1.690255000000         3.393043000000         2.390035000000\n");
# 	viewer_17791769743211622.setViewStyle({"style": "outline", "width": 0.05});
# 	viewer_17791769743211622.setStyle({"stick": {}, "sphere": {"scale": 0.25}});
# 	viewer_17791769743211622.zoomTo();
# viewer_17791769743211622.render();
# });
# </script>

# %%
# Build force field (pre-computed RESP charges provided)
# partial_charges = [...]  # (see full list in Conformers.ipynb)

ff_gen = vlx.MMForceFieldGenerator()

ff_gen.create_topology(penicilin)

opm_dyn = vlx.OpenMMDynamics()
opm_dyn.create_system_from_molecule(penicilin,
                                    ff_gen,
                                    filename='penicilin',
                                    residue_name='MOL')
# Out:
# * Info * Using 6-31G* basis set for RESP charges...
# * Info * Sum of partial charges is not a whole number.
# * Info * Compensating by removing -4.000e-06 from the largest charge.
#
# * Info * Using GAFF (v2.11) parameters.
#          Reference: J. Wang, R. M. Wolf, J. W. Caldwell, P. A. Kollman, D. A. Case, J. Comput. Chem. 2004,
#          25, 1157-1174.
#
# * Info * Updated bond length 4-8 (n -c ) to 0.148 nm
# * Info * Updated bond length 5-7 (cy-cy) to 0.145 nm
# * Info * Updated bond length 7-8 (cy-c ) to 0.150 nm
# * Info * Updated bond angle 3-4-8 (c3-n -c ) to 133.182 deg
# * Info * Updated bond angle 4-5-7 (n -cy-cy) to 93.704 deg
# * Info * Updated bond angle 4-8-7 (n -c -cy) to 89.674 deg
# * Info * Updated bond angle 4-8-9 (n -c -o ) to 135.082 deg
# * Info * Updated bond angle 5-4-8 (cy-n -c ) to 88.825 deg
# * Info * Updated bond angle 20-22-38 (c -oh-ho) to 120.916 deg
# * Info * System parameters written to penicilin_system.xml
# * Info * System coordinates written to penicilin_system.pdb

# %%
# High-temperature conformational sampling
conformers_dict = opm_dyn.conformational_sampling(
    ensemble='NVT',
    temperature=1000,
    timestep=2.0,
    nsteps=10000,
    snapshots=500,
    unique_conformers=True,
    qm_driver=None,
    basis=None,
    constraints=None
)
# Out:
# * Info * Minimized energy: -223.06078338623047
# * Info * Saved coordinates for step 20
# * Info * Minimized energy: -223.07109832763672
# * Info * Saved coordinates for step 40
# * Info * Minimized energy: -223.2802734375
# * Info * Saved coordinates for step 60
# * Info * Minimized energy: -223.06390380859375
# * Info * Saved coordinates for step 80
# * Info * Minimized energy: -222.95046997070312
# * Info * Saved coordinates for step 100
# * Info * Minimized energy: -223.1204071044922
# * Info * Saved coordinates for step 120
# * Info * Minimized energy: -223.0752716064453
# * Info * Saved coordinates for step 140
# * Info * Minimized energy: -223.28565216064453
# * Info * Saved coordinates for step 160
# * Info * Minimized energy: -223.37567138671875
# * Info * Saved coordinates for step 180
# * Info * Minimized energy: -222.04891204833984
# * Info * Saved coordinates for step 200
# * Info * Minimized energy: -219.56442260742188
# * Info * Saved coordinates for step 220
# * Info * Minimized energy: -221.38113403320312
# * Info * Saved coordinates for step 240
# * Info * Minimized energy: -221.1193618774414
# * Info * Saved coordinates for step 260
# * Info * Minimized energy: -221.13072967529297
# * Info * Saved coordinates for step 280
# * Info * Minimized energy: -220.86215209960938
# * Info * Saved coordinates for step 300
# * Info * Minimized energy: -220.4615020751953
# * Info * Saved coordinates for step 320
# * Info * Minimized energy: -219.7935028076172
# * Info * Saved coordinates for step 340
# * Info * Minimized energy: -221.0874252319336
# * Info * Saved coordinates for step 360
# * Info * Minimized energy: -221.29190063476562
# * Info * Saved coordinates for step 380
# * Info * Minimized energy: -220.4681625366211
# * Info * Saved coordinates for step 400
# * Info * Minimized energy: -220.42764282226562
# * Info * Saved coordinates for step 420
# * Info * Minimized energy: -221.26124572753906
# * Info * Saved coordinates for step 440
# * Info * Minimized energy: -220.86070251464844
# * Info * Saved coordinates for step 460
# * Info * Minimized energy: -220.3452911376953
# * Info * Saved coordinates for step 480
# * Info * Minimized energy: -221.13653564453125
# * Info * Saved coordinates for step 500
# * Info * Minimized energy: -220.88326263427734
# * Info * Saved coordinates for step 520
# * Info * Minimized energy: -221.11471557617188
# * Info * Saved coordinates for step 540
# * Info * Minimized energy: -221.08818817138672
# * Info * Saved coordinates for step 560
# * Info * Minimized energy: -211.87406158447266
# * Info * Saved coordinates for step 580
# * Info * Minimized energy: -215.1709747314453
# * Info * Saved coordinates for step 600
# * Info * Minimized energy: -215.20256805419922
# * Info * Saved coordinates for step 620
# * Info * Minimized energy: -217.10269165039062
# * Info * Saved coordinates for step 640
# * Info * Minimized energy: -216.42098999023438
# * Info * Saved coordinates for step 660
# * Info * Minimized energy: -216.93113708496094
# * Info * Saved coordinates for step 680
# * Info * Minimized energy: -216.43553924560547
# * Info * Saved coordinates for step 700
# * Info * Minimized energy: -217.0252914428711
# * Info * Saved coordinates for step 720
# * Info * Minimized energy: -216.57052612304688
# * Info * Saved coordinates for step 740
# * Info * Minimized energy: -216.55885314941406
# * Info * Saved coordinates for step 760
# * Info * Minimized energy: -216.52973175048828
# * Info * Saved coordinates for step 780
# * Info * Minimized energy: -216.64279174804688
# * Info * Saved coordinates for step 800
# * Info * Minimized energy: -222.7440948486328
# * Info * Saved coordinates for step 820
# * Info * Minimized energy: -217.15975952148438
# * Info * Saved coordinates for step 840
# * Info * Minimized energy: -222.35960388183594
# * Info * Saved coordinates for step 860
# * Info * Minimized energy: -220.41039276123047
# * Info * Saved coordinates for step 880
# * Info * Minimized energy: -214.19406127929688
# * Info * Saved coordinates for step 900
# * Info * Minimized energy: -220.12823486328125
# * Info * Saved coordinates for step 920
# * Info * Minimized energy: -220.3346939086914
# * Info * Saved coordinates for step 940
# * Info * Minimized energy: -219.8551483154297
# * Info * Saved coordinates for step 960
# * Info * Minimized energy: -220.28587341308594
# * Info * Saved coordinates for step 980
# * Info * Minimized energy: -213.61207580566406
# * Info * Saved coordinates for step 1000
# * Info * Minimized energy: -220.28033447265625
# * Info * Saved coordinates for step 1020
# * Info * Minimized energy: -214.55270385742188
# * Info * Saved coordinates for step 1040
# * Info * Minimized energy: -213.3842010498047
# * Info * Saved coordinates for step 1060
# * Info * Minimized energy: -213.89776611328125
# * Info * Saved coordinates for step 1080
# * Info * Minimized energy: -212.9483642578125
# * Info * Saved coordinates for step 1100
# * Info * Minimized energy: -212.96044921875
# * Info * Saved coordinates for step 1120
# * Info * Minimized energy: -211.00718688964844
# * Info * Saved coordinates for step 1140
# * Info * Minimized energy: -222.8779754638672
# * Info * Saved coordinates for step 1160
# * Info * Minimized energy: -214.51480102539062
# * Info * Saved coordinates for step 1180
# * Info * Minimized energy: -222.78570556640625
# * Info * Saved coordinates for step 1200
# * Info * Minimized energy: -222.77349853515625
# * Info * Saved coordinates for step 1220
# * Info * Minimized energy: -222.93244171142578
# * Info * Saved coordinates for step 1240
# * Info * Minimized energy: -214.28851318359375
# * Info * Saved coordinates for step 1260
# * Info * Minimized energy: -211.01773071289062
# * Info * Saved coordinates for step 1280
# * Info * Minimized energy: -213.52069091796875
# * Info * Saved coordinates for step 1300
# * Info * Minimized energy: -214.60717010498047
# * Info * Saved coordinates for step 1320
# * Info * Minimized energy: -214.954833984375
# * Info * Saved coordinates for step 1340
# * Info * Minimized energy: -214.91564178466797
# * Info * Saved coordinates for step 1360
# * Info * Minimized energy: -220.1373291015625
# * Info * Saved coordinates for step 1380
# * Info * Minimized energy: -219.99656677246094
# * Info * Saved coordinates for step 1400
# * Info * Minimized energy: -221.74270629882812
# * Info * Saved coordinates for step 1420
# * Info * Minimized energy: -221.98159790039062
# * Info * Saved coordinates for step 1440
# * Info * Minimized energy: -217.25089263916016
# * Info * Saved coordinates for step 1460
# * Info * Minimized energy: -222.8492134301793
# * Info * Saved coordinates for step 1480
# * Info * Minimized energy: -223.077225492645
# * Info * Saved coordinates for step 1500
# * Info * Minimized energy: -222.90972271459106
# * Info * Saved coordinates for step 1520
# * Info * Minimized energy: -223.01753333404034
# * Info * Saved coordinates for step 1540
# * Info * Minimized energy: -223.24002175236143
# * Info * Saved coordinates for step 1560
# * Info * Minimized energy: -223.3866357368525
# * Info * Saved coordinates for step 1580
# * Info * Minimized energy: -223.33020384545418
# * Info * Saved coordinates for step 1600
# * Info * Minimized energy: -223.31326831253688
# * Info * Saved coordinates for step 1620
# * Info * Minimized energy: -223.3345106467132
# * Info * Saved coordinates for step 1640
# * Info * Minimized energy: -223.3728976494655
# * Info * Saved coordinates for step 1660
# * Info * Minimized energy: -221.1695886150888
# * Info * Saved coordinates for step 1680
# * Info * Minimized energy: -221.08208200678052
# * Info * Saved coordinates for step 1700
# * Info * Minimized energy: -221.0746293109653
# * Info * Saved coordinates for step 1720
# * Info * Minimized energy: -221.1456692993757
# * Info * Saved coordinates for step 1740
# * Info * Minimized energy: -221.36295670391883
# * Info * Saved coordinates for step 1760
# * Info * Minimized energy: -221.41093127891222
# * Info * Saved coordinates for step 1780
# * Info * Minimized energy: -224.53076640534601
# * Info * Saved coordinates for step 1800
# * Info * Minimized energy: -224.62248653818426
# * Info * Saved coordinates for step 1820
# * Info * Minimized energy: -218.8251605218451
# * Info * Saved coordinates for step 1840
# * Info * Minimized energy: -218.92519686887297
# * Info * Saved coordinates for step 1860
# * Info * Minimized energy: -219.05660888579786
# * Info * Saved coordinates for step 1880
# * Info * Minimized energy: -219.05140122400525
# * Info * Saved coordinates for step 1900
# * Info * Minimized energy: -219.09737645318145
# * Info * Saved coordinates for step 1920
# * Info * Minimized energy: -219.09568903815426
# * Info * Saved coordinates for step 1940
# * Info * Minimized energy: -219.0703591171611
# * Info * Saved coordinates for step 1960
# * Info * Minimized energy: -219.11494245767938
# * Info * Saved coordinates for step 1980
# * Info * Minimized energy: -219.07979448276527
# * Info * Saved coordinates for step 2000
# * Info * Minimized energy: -219.04983629871302
# * Info * Saved coordinates for step 2020
# * Info * Minimized energy: -219.09639842245437
# * Info * Saved coordinates for step 2040
# * Info * Minimized energy: -219.0843715931229
# * Info * Saved coordinates for step 2060
# * Info * Minimized energy: -219.14462482826073
# * Info * Saved coordinates for step 2080
# * Info * Minimized energy: -219.12682437503457
# * Info * Saved coordinates for step 2100
# * Info * Minimized energy: -224.5787243569792
# * Info * Saved coordinates for step 2120
# * Info * Minimized energy: -224.2568033364667
# * Info * Saved coordinates for step 2140
# * Info * Minimized energy: -224.57164370318685
# * Info * Saved coordinates for step 2160
# * Info * Minimized energy: -221.40033407876803
# * Info * Saved coordinates for step 2180
# * Info * Minimized energy: -221.17854613789623
# * Info * Saved coordinates for step 2200
# * Info * Minimized energy: -221.17052225916808
# * Info * Saved coordinates for step 2220
# * Info * Minimized energy: -221.14741740848578
# * Info * Saved coordinates for step 2240
# * Info * Minimized energy: -221.19437005550049
# * Info * Saved coordinates for step 2260
# * Info * Minimized energy: -221.30749948515145
# * Info * Saved coordinates for step 2280
# * Info * Minimized energy: -221.37012660445666
# * Info * Saved coordinates for step 2300
# * Info * Minimized energy: -221.41381300052723
# * Info * Saved coordinates for step 2320
# * Info * Minimized energy: -222.91951097362812
# * Info * Saved coordinates for step 2340
# * Info * Minimized energy: -222.91106386584235
# * Info * Saved coordinates for step 2360
# * Info * Minimized energy: -222.75437022015467
# * Info * Saved coordinates for step 2380
# * Info * Minimized energy: -223.26669769925232
# * Info * Saved coordinates for step 2400
# * Info * Minimized energy: -223.21335018579776
# * Info * Saved coordinates for step 2420
# * Info * Minimized energy: -222.88651331711796
# * Info * Saved coordinates for step 2440
# * Info * Minimized energy: -223.18648259891606
# * Info * Saved coordinates for step 2460
# * Info * Minimized energy: -223.41760120603195
# * Info * Saved coordinates for step 2480
# * Info * Minimized energy: -223.36890403354428
# * Info * Saved coordinates for step 2500
# * Info * Minimized energy: -223.18147626855938
# * Info * Saved coordinates for step 2520
# * Info * Minimized energy: -222.74814118360402
# * Info * Saved coordinates for step 2540
# * Info * Minimized energy: -223.1766892606958
# * Info * Saved coordinates for step 2560
# * Info * Minimized energy: -222.98738228202257
# * Info * Saved coordinates for step 2580
# * Info * Minimized energy: -223.35782888473392
# * Info * Saved coordinates for step 2600
# * Info * Minimized energy: -223.46219216851827
# * Info * Saved coordinates for step 2620
# * Info * Minimized energy: -223.41198765894228
# * Info * Saved coordinates for step 2640
# * Info * Minimized energy: -223.3986680576629
# * Info * Saved coordinates for step 2660
# * Info * Minimized energy: -223.37719435045977
# * Info * Saved coordinates for step 2680
# * Info * Minimized energy: -223.40571660342468
# * Info * Saved coordinates for step 2700
# * Info * Minimized energy: -223.35837505971406
# * Info * Saved coordinates for step 2720
# * Info * Minimized energy: -223.4833173809445
# * Info * Saved coordinates for step 2740
# * Info * Minimized energy: -223.44913593955994
# * Info * Saved coordinates for step 2760
# * Info * Minimized energy: -223.46393192749937
# * Info * Saved coordinates for step 2780
# * Info * Minimized energy: -223.46323352907189
# * Info * Saved coordinates for step 2800
# * Info * Minimized energy: -223.4550357853259
# * Info * Saved coordinates for step 2820
# * Info * Minimized energy: -223.35773899289552
# * Info * Saved coordinates for step 2840
# * Info * Minimized energy: -223.30704075508703
# * Info * Saved coordinates for step 2860
# * Info * Minimized energy: -223.3842818846801
# * Info * Saved coordinates for step 2880
# * Info * Minimized energy: -223.29962915460789
# * Info * Saved coordinates for step 2900
# * Info * Minimized energy: -223.2338908158319
# * Info * Saved coordinates for step 2920
# * Info * Minimized energy: -223.23755650882688
# * Info * Saved coordinates for step 2940
# * Info * Minimized energy: -223.38750381451464
# * Info * Saved coordinates for step 2960
# * Info * Minimized energy: -223.4459724946911
# * Info * Saved coordinates for step 2980
# * Info * Minimized energy: -223.41083437933682
# * Info * Saved coordinates for step 3000
# * Info * Minimized energy: -223.41029743648335
# * Info * Saved coordinates for step 3020
# * Info * Minimized energy: -223.43137953560858
# * Info * Saved coordinates for step 3040
# * Info * Minimized energy: -223.30591116278998
# * Info * Saved coordinates for step 3060
# * Info * Minimized energy: -223.45492994042303
# * Info * Saved coordinates for step 3080
# * Info * Minimized energy: -223.3835800137149
# * Info * Saved coordinates for step 3100
# * Info * Minimized energy: -223.42734185557921
# * Info * Saved coordinates for step 3120
# * Info * Minimized energy: -223.46150134369074
# * Info * Saved coordinates for step 3140
# * Info * Minimized energy: -223.49383270584445
# * Info * Saved coordinates for step 3160
# * Info * Minimized energy: -223.46378863322823
# * Info * Saved coordinates for step 3180
# * Info * Minimized energy: -223.4572534603236
# * Info * Saved coordinates for step 3200
# * Info * Minimized energy: -223.30905234043752
# * Info * Saved coordinates for step 3220
# * Info * Minimized energy: -223.12226829692804
# * Info * Saved coordinates for step 3240
# * Info * Minimized energy: -222.94976732880426
# * Info * Saved coordinates for step 3260
# * Info * Minimized energy: -221.34735343877847
# * Info * Saved coordinates for step 3280
# * Info * Minimized energy: -221.17394577982773
# * Info * Saved coordinates for step 3300
# * Info * Minimized energy: -220.9738888373501
# * Info * Saved coordinates for step 3320
# * Info * Minimized energy: -220.94478234062228
# * Info * Saved coordinates for step 3340
# * Info * Minimized energy: -220.79788280879572
# * Info * Saved coordinates for step 3360
# * Info * Minimized energy: -221.08463291018032
# * Info * Saved coordinates for step 3380
# * Info * Minimized energy: -220.92687358084572
# * Info * Saved coordinates for step 3400
# * Info * Minimized energy: -221.36272572885872
# * Info * Saved coordinates for step 3420
# * Info * Minimized energy: -221.06942150297763
# * Info * Saved coordinates for step 3440
# * Info * Minimized energy: -220.97286425349841
# * Info * Saved coordinates for step 3460
# * Info * Minimized energy: -221.16518699855402
# * Info * Saved coordinates for step 3480
# * Info * Minimized energy: -221.09526670245398
# * Info * Saved coordinates for step 3500
# * Info * Minimized energy: -221.3073138910038
# * Info * Saved coordinates for step 3520
# * Info * Minimized energy: -221.37988885390197
# * Info * Saved coordinates for step 3540
# * Info * Minimized energy: -221.3349344633596
# * Info * Saved coordinates for step 3560
# * Info * Minimized energy: -221.21482074576255
# * Info * Saved coordinates for step 3580
# * Info * Minimized energy: -221.27009720462885
# * Info * Saved coordinates for step 3600
# * Info * Minimized energy: -221.42661277764543
# * Info * Saved coordinates for step 3620
# * Info * Minimized energy: -221.39657987137326
# * Info * Saved coordinates for step 3640
# * Info * Minimized energy: -223.0291620295636
# * Info * Saved coordinates for step 3660
# * Info * Minimized energy: -223.35001770457598
# * Info * Saved coordinates for step 3680
# * Info * Minimized energy: -223.28207613702472
# * Info * Saved coordinates for step 3700
# * Info * Minimized energy: -223.38849751586687
# * Info * Saved coordinates for step 3720
# * Info * Minimized energy: -223.43946889830994
# * Info * Saved coordinates for step 3740
# * Info * Minimized energy: -223.39411521382394
# * Info * Saved coordinates for step 3760
# * Info * Minimized energy: -223.3694391858677
# * Info * Saved coordinates for step 3780
# * Info * Minimized energy: -223.31706879432414
# * Info * Saved coordinates for step 3800
# * Info * Minimized energy: -215.33906427310095
# * Info * Saved coordinates for step 3820
# * Info * Minimized energy: -221.60088551145415
# * Info * Saved coordinates for step 3840
# * Info * Minimized energy: -228.96838079543528
# * Info * Saved coordinates for step 3860
# * Info * Minimized energy: -228.92217382296502
# * Info * Saved coordinates for step 3880
# * Info * Minimized energy: -228.9899666508082
# * Info * Saved coordinates for step 3900
# ...
# * Info * Minimized energy: -223.158365132214
# * Info * Saved coordinates for step 8760
# * Info * Minimized energy: -223.42948049451277
# * Info * Saved coordinates for step 8780
# * Info * Minimized energy: -223.37558461276154
# * Info * Saved coordinates for step 8800
# * Info * Minimized energy: -223.40182277216897
# * Info * Saved coordinates for step 8820
# * Info * Minimized energy: -223.36640365684832
# * Info * Saved coordinates for step 8840
# * Info * Minimized energy: -223.46046863083703
# * Info * Saved coordinates for step 8860
# * Info * Minimized energy: -223.41365594446793
# * Info * Saved coordinates for step 8880
# * Info * Minimized energy: -223.4369772158729
# * Info * Saved coordinates for step 8900
# * Info * Minimized energy: -223.43630907951425
# * Info * Saved coordinates for step 8920
# * Info * Minimized energy: -223.4260696253279
# * Info * Saved coordinates for step 8940
# * Info * Minimized energy: -223.3874252312243
# * Info * Saved coordinates for step 8960
# * Info * Minimized energy: -223.37876210680673
# * Info * Saved coordinates for step 8980
# * Info * Minimized energy: -223.39057685479776
# * Info * Saved coordinates for step 9000
# * Info * Minimized energy: -223.43363926199908
# * Info * Saved coordinates for step 9020
# * Info * Minimized energy: -229.01645949643165
# * Info * Saved coordinates for step 9040
# * Info * Minimized energy: -223.46348729508645
# * Info * Saved coordinates for step 9060
# * Info * Minimized energy: -223.50586996747734
# * Info * Saved coordinates for step 9080
# * Info * Minimized energy: -223.51815052215358
# * Info * Saved coordinates for step 9100
# * Info * Minimized energy: -223.37618206232898
# * Info * Saved coordinates for step 9120
# * Info * Minimized energy: -223.5042892980075
# * Info * Saved coordinates for step 9140
# * Info * Minimized energy: -223.4758265628975
# * Info * Saved coordinates for step 9160
# * Info * Minimized energy: -223.43612844019262
# * Info * Saved coordinates for step 9180
# * Info * Minimized energy: -223.4155504206843
# * Info * Saved coordinates for step 9200
# * Info * Minimized energy: -223.3740855619981
# * Info * Saved coordinates for step 9220
# * Info * Minimized energy: -223.3278325503798
# * Info * Saved coordinates for step 9240
# * Info * Minimized energy: -227.99624746860553
# * Info * Saved coordinates for step 9260
# * Info * Minimized energy: -227.9627886597678
# * Info * Saved coordinates for step 9280
# * Info * Minimized energy: -228.1391871233098
# * Info * Saved coordinates for step 9300
# * Info * Minimized energy: -228.1299205510604
# * Info * Saved coordinates for step 9320
# * Info * Minimized energy: -233.25844896277596
# * Info * Saved coordinates for step 9340
# * Info * Minimized energy: -228.77069322081783
# * Info * Saved coordinates for step 9360
# * Info * Minimized energy: -228.67519107552278
# * Info * Saved coordinates for step 9380
# * Info * Minimized energy: -228.40796166372198
# * Info * Saved coordinates for step 9400
# * Info * Minimized energy: -228.0074513551146
# * Info * Saved coordinates for step 9420
# * Info * Minimized energy: -227.9453181497332
# * Info * Saved coordinates for step 9440
# * Info * Minimized energy: -227.91460642687244
# * Info * Saved coordinates for step 9460
# * Info * Minimized energy: -227.86734575184687
# * Info * Saved coordinates for step 9480
# * Info * Minimized energy: -227.93089096054302
# * Info * Saved coordinates for step 9500
# * Info * Minimized energy: -227.83746781080436
# * Info * Saved coordinates for step 9520
# * Info * Minimized energy: -227.90784034855517
# * Info * Saved coordinates for step 9540
# * Info * Minimized energy: -227.8202198474885
# * Info * Saved coordinates for step 9560
# * Info * Minimized energy: -227.9589945595578
# * Info * Saved coordinates for step 9580
# * Info * Minimized energy: -227.9429861708246
# * Info * Saved coordinates for step 9600
# * Info * Minimized energy: -227.8936204258361
# * Info * Saved coordinates for step 9620
# * Info * Minimized energy: -227.89380676916755
# * Info * Saved coordinates for step 9640
# * Info * Minimized energy: -227.90660261541908
# * Info * Saved coordinates for step 9660
# * Info * Minimized energy: -227.98629351232566
# * Info * Saved coordinates for step 9680
# * Info * Minimized energy: -227.99081508958875
# * Info * Saved coordinates for step 9700
# * Info * Minimized energy: -228.0898887781578
# * Info * Saved coordinates for step 9720
# * Info * Minimized energy: -224.18980704239618
# * Info * Saved coordinates for step 9740
# * Info * Minimized energy: -224.89708881647022
# * Info * Saved coordinates for step 9760
# * Info * Minimized energy: -224.98585093366495
# * Info * Saved coordinates for step 9780
# * Info * Minimized energy: -224.993010849989
# * Info * Saved coordinates for step 9800
# * Info * Minimized energy: -224.9505966931745
# * Info * Saved coordinates for step 9820
# * Info * Minimized energy: -224.7798401861322
# * Info * Saved coordinates for step 9840
# * Info * Minimized energy: -224.8420598833027
# * Info * Saved coordinates for step 9860
# * Info * Minimized energy: -224.87930578307427
# * Info * Saved coordinates for step 9880
# * Info * Minimized energy: -224.84291278974203
# * Info * Saved coordinates for step 9900
# * Info * Minimized energy: -224.92400545632523
# * Info * Saved coordinates for step 9920
# * Info * Minimized energy: -224.8765877710552
# * Info * Saved coordinates for step 9940
# * Info * Minimized energy: -224.88014706934024
# * Info * Saved coordinates for step 9960
# * Info * Minimized energy: -224.82714891314254
# * Info * Saved coordinates for step 9980
# * Info * Minimized energy: -224.88065028529306
# * Info * Saved coordinates for step 10000
# * Info * Conformational sampling completed!
# * Info * Number of conformations: 500
# * Info * Filtering for unique conformers
# * Info *
# Number of unique conformers: 12

# %%
# Visualise and plot energy distribution
opm_dyn.show_conformers(number=5)

import matplotlib.pyplot as plt
import numpy as np

E_rel = np.array(conformers_dict['energies']) - np.min(conformers_dict['energies'])

plt.figure(figsize=(8, 4))
plt.hist(E_rel, bins=50, color='darkcyan', alpha=0.7)
plt.xlabel('Relative energy [kJ/mol]')
plt.ylabel('Number of conformers')
plt.title('Conformer energy distribution — penicilin')
plt.tight_layout()
plt.show()

# Save global minimum
conformers_dict['molecules'][0].show()
conformers_dict['molecules'][0].write_xyz_file('penicilin-global-min.xyz')
# Out:
# * Info *
# Conformation 1: Energy: -233.449 kJ/mol, Weight: 0.6212
# <div id="3dmolviewer_17791770791930654"  style="position: relative; width: 400px; height: 300px;">
#         <p id="3dmolwarning_17791770791930654" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdn.jsdelivr.net/npm/3dmol@2.5.4/build/3Dmol-min.js');
# }
#
# var viewer_17791770791930654 = null;
# var warn = document.getElementById("3dmolwarning_17791770791930654");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17791770791930654 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17791770791930654"),{backgroundColor:"white"});
# viewer_17791770791930654.zoomTo();
# 	viewer_17791770791930654.addModel("41\n\nC              0.546778681594        -3.127288896384        -0.654459549697\nC             -0.829923746339        -2.801748691641        -1.284463644260\nC             -1.996898499157        -3.445932958510        -0.440132561297\nN             -2.229725427584        -2.415617058691         0.546930199416\nC             -2.238967834387        -1.026559666289         0.219482999606\nS             -1.029729916773        -0.952278886283        -1.173684178544\nC             -1.888257560970        -0.632533079035         1.582599758273\nC             -1.634195584319        -2.087007837879         1.856403766936\nO             -1.067747169128        -2.747612028421         2.762790963846\nN             -0.666765299508         0.191789259867         1.707699855833\nC             -0.656841062333         1.589064992951         1.417138888941\nO             -1.734153595902         2.186942153949         1.161356172363\nC              0.635244354741         2.339827520520         1.397408411172\nC              1.703807871293         1.505233570308         0.733185121752\nC              2.730427222787         0.906747155576         1.499241357889\nC              3.690788438049         0.088340922814         0.880649612270\nC              3.634040380739        -0.141747029926        -0.502784944924\nC              2.618764314454         0.447976416722        -1.271886427442\nC              1.658184615329         1.269203058378        -0.658873512791\nC             -3.274355836095        -3.759554476868        -1.193480580821\nO             -3.992382913992        -2.863042309798        -1.701441897434\nO             -3.695861708627        -5.055395539748        -1.365103646944\nC             -0.766550405504        -3.204165054747        -2.774904446647\nH              1.359058229097        -2.580648191301        -1.180384368987\nH              0.771047342450        -4.213262172958        -0.710581453524\nH              0.590842470372        -2.828264875829         0.414891257402\nH             -1.679252715591        -4.389075501978         0.059161906017\nH             -3.253471124267        -0.691020476132        -0.089404821616\nH             -2.740672790540        -0.253912301966         2.187684848987\nH              0.251094763578        -0.274558486545         
480580821\nO             -3.992382913992        -2.863042309798        -1.701441897434\nO             -3.695861708627        -5.055395539748        -1.365103646944\nC             -0.766550405504        -3.204165054747        -2.774904446647\nH              1.359058229097        -2.580648191301        -1.180384368987\nH              0.771047342450        -4.213262172958        -0.710581453524\nH              0.590842470372        -2.828264875829         0.414891257402\nH             -1.679252715591        -4.389075501978         0.059161906017\nH             -3.253471124267        -0.691020476132        -0.089404821616\nH             -2.740672790540        -0.253912301966         2.187684848987\nH              0.251094763578        -0.274558486545         1.888769947354\nH              0.495090548297         3.299152182198         0.853819589388\nH              0.924841384157         2.599490286734         2.439058888039\nH              2.787017587075         1.067786743068         2.568993567349\nH              4.474948564968        -0.367131527738         1.470732554184\nH              4.373178988130        -0.773929793494        -0.977557315036\nH              2.571783366734         0.266654420625        -2.337911778761\nH              0.872138808818         1.703414134238        -1.264137939676\nH             -4.567611720525        -5.127888987470        -1.876152301229\nH              0.095058919419        -2.716809252326        -3.279690256906\nH             -1.676085715156        -2.868921342380        -3.316883778399\nH             -0.665691098820        -4.304538241831        -2.888839227809\n");
# 	viewer_17791770792948794.setViewStyle({"style": "outline", "width": 0.05});
# 	viewer_17791770792948794.setStyle({"stick": {}, "sphere": {"scale": 0.25}});
# 	viewer_17791770792948794.zoomTo();
# viewer_17791770792948794.render();
# });
# </script>

# %% [markdown]
# # Part 3 — Environment: Solvation and QM/MM
#
# The geometry and properties of a molecule depend strongly on its environment. VeloxChem supports three levels of description:
#
# | Level | Model | Cost |
# |-------|-------|------|
# | Implicit | CPCM / SMD | Cheap — continuum dielectric |
# | Explicit MM | Classical point charges | Medium — no polarisation of environment |
#
#
# ---
#
# ## 3.1 Implicit solvation — CPCM
#
# In the **conductor-like polarizable continuum model (CPCM)**, the solute sits inside a cavity defined by its molecular surface. The surrounding medium is treated as a conductor (dielectric constant → ∞) and the result is rescaled to the desired permittivity $\epsilon$.
#
# VeloxChem uses CPCM for SCF energies, gradients, and linear-response spectra.
#
# Key parameters:
# - `solvation_model = "cpcm"` — activates CPCM
# - `cpcm_epsilon` — solvent permittivity (default: 78.39 for water)

# %%
import veloxchem as vlx

molecule = vlx.Molecule.read_name('ammonia')
basis    = vlx.MolecularBasis.read(molecule, 'def2-svp')

scf_drv = vlx.ScfRestrictedDriver()
scf_drv.xcfun = 'b3lyp'
scf_drv.solvation_model = 'cpcm'
# scf_drv.cpcm_epsilon = 24.5  # ethanol — change here for other solvents
scf_results = scf_drv.compute(molecule, basis)

# UV/vis with CPCM
rsp_drv = vlx.LinearResponseEigenSolver()
rsp_drv.nstates = 5
rsp_results = rsp_drv.compute(molecule, basis, scf_results)
# Out:
# Reading ammonia from PubChem...
#
# Reference: S. Kim, J. Chen, T. Cheng, A. Gindulyte, J. He, S. He, Q. Li, B. A. Shoemaker, P. A. Thiessen, B. Yu, L. Zaslavsky, J. Zhang, E. E. Bolton, Nucleic Acids Res., 2025, 53, D1516-D1525.
#
# Please double-check the compound since names may refer to more than one record.
#
#
#                                             Self Consistent Field Driver Setup
#                                            ====================================
#
#                    Wave Function Model             : Spin-Restricted Kohn-Sham
#                    Initial Guess Model             : Superposition of Atomic Densities
#                    Convergence Accelerator         : Two Level Direct Inversion of Iterative Subspace
#                    Max. Number of Iterations       : 50
#                    Max. Number of Error Vectors    : 10
#                    Convergence Threshold           : 1.0e-06
#                    ERI Screening Threshold         : 1.0e-12
#                    Linear Dependence Threshold     : 1.0e-06
#                    Exchange-Correlation Functional : B3LYP
#                    Molecular Grid Level            : 4
#                    Solvation Model                 : C-PCM with ISWIG Discretization
#                    C-PCM Dielectric Constant       : 78.39
#                    C-PCM Points per Hydrogen Sphere: 110
#                    C-PCM Points per non-H Sphere   : 194
#
# * Info * Using the B3LYP functional.
#
#          P. J. Stephens, F. J. Devlin, C. F. Chabalowski, and M. J. Frisch.,  J. Phys. Chem. 98, 11623 (1994)
#
# * Info * Using the Libxc library (v7.0.0).
#
#          S. Lehtola, C. Steigemann, M. J.T. Oliveira, and M. A.L. Marques.,  SoftwareX 7, 1–5 (2018)
#
# * Info * Using the following algorithm for XC numerical integration.
#
#          J. Kussmann, H. Laqua and C. Ochsenfeld, J. Chem. Theory Comput. 2021, 17, 1512-1521
#
# * Info * Using C-PCM with the ISWIG discretization method.
#
#          A. W. Lange, J. M. Herbert, J. Chem. Phys. 2010, 133, 244111.
#
# * Info * Starting Reduced Basis SCF calculation...
# * Info * ...done. SCF energy in reduced basis set: -56.117339115040 a.u. Time: 0.07 sec.
#
#
#                Iter. |    Kohn-Sham Energy | Energy Change | Gradient Norm | Max. Gradient | Density Change
#                --------------------------------------------------------------------------------------------
#                   1       -56.512716137614    0.0000000000      0.15023797      0.01923001      0.00000000
#                   2       -56.513489106673   -0.0007729691      0.13041261      0.01401348      0.08226374
#                   3       -56.515265593659   -0.0017764870      0.01902058      0.00240245      0.03568634
#                   4       -56.515302443278   -0.0000368496      0.00097882      0.00012714      0.00482937
#                   5       -56.515302575783   -0.0000001325      0.00007504      0.00000989      0.00052594
#                   6       -56.515302577009   -0.0000000012      0.00000168      0.00000023      0.00007675
#                   7       -56.515302577012   -0.0000000000      0.00000018      0.00000003      0.00000208
#
#                *** SCF converged in 7 iterations. Time: 0.90 sec.
#
#                Spin-Restricted Kohn-Sham:
#                --------------------------
#                Total Energy                       :      -56.5153025770 a.u.
#                Electronic Energy                  :      -68.0946625667 a.u.
#                Electrostatic Solvation Energy     :       -0.0080236471 a.u.
#                Nuclear Repulsion Energy           :       11.5873836369 a.u.
#                ------------------------------------
#                Gradient Norm                      :        0.0000001819 a.u.
#
#
#                Ground State Information
#                ------------------------
#                Charge of Molecule            :  0.0
#                Multiplicity (2S+1)           :  1
#                Magnetic Quantum Number (M_S) :  0.0
#
#
#                                             Linear Response EigenSolver Setup
#                                            ===================================
#
#                                Number of States                : 5
#                                Max. Number of Iterations       : 150
#                                Convergence Threshold           : 1.0e-04
#                                ERI Screening Threshold         : 1.0e-12
#                                Exchange-Correlation Functional : B3LYP
#                                Molecular Grid Level            : 4
#                                Solvation Model                 : C-PCM
#                                C-PCM Points per Hydrogen Sphere: 110
#                                C-PCM Points per non-H Sphere   : 194
#                                Non-Equilibrium solvation       : True
#                                C-PCM Dielectric Constant       : 78.39
#                                C-PCM Optical Dielectric Const. : 1.777849
#
# * Info * Using the B3LYP functional.
#
#          P. J. Stephens, F. J. Devlin, C. F. Chabalowski, and M. J. Frisch.,  J. Phys. Chem. 98, 11623 (1994)
#
# * Info * Using the Libxc library (v7.0.0).
#
#          S. Lehtola, C. Steigemann, M. J.T. Oliveira, and M. A.L. Marques.,  SoftwareX 7, 1–5 (2018)
#
# * Info * Using the following algorithm for XC numerical integration.
#
#          J. Kussmann, H. Laqua and C. Ochsenfeld, J. Chem. Theory Comput. 2021, 17, 1512-1521
#
# * Info * Using C-PCM with the ISWIG discretization method.
#
#          A. W. Lange, J. M. Herbert, J. Chem. Phys. 2010, 133, 244111.
#
# * Info * 15 gerade trial vectors in reduced space
# * Info * 15 ungerade trial vectors in reduced space
#
#                *** Iteration:   1 * Residuals (Max,Min): 1.41e-01 and 1.15e-01
#
# * Info * 20 gerade trial vectors in reduced space
# * Info * 20 ungerade trial vectors in reduced space
#
#                *** Iteration:   2 * Residuals (Max,Min): 1.53e-02 and 6.06e-03
#
# * Info * 25 gerade trial vectors in reduced space
# * Info * 25 ungerade trial vectors in reduced space
#
#                *** Iteration:   3 * Residuals (Max,Min): 1.45e-03 and 3.78e-04
#
# * Info * 30 gerade trial vectors in reduced space
# * Info * 30 ungerade trial vectors in reduced space
#
#                *** Iteration:   4 * Residuals (Max,Min): 7.54e-05 and 1.66e-05
#
#                *** Linear response converged in 4 iterations. Time: 0.75 sec
#
#
#                Electric Transition Dipole Moments (dipole length, a.u.)
#                --------------------------------------------------------
#                                                 X            Y            Z
#                Excited State    S1:      0.182219    -0.251116    -0.349960
#                Excited State    S2:      0.345605     0.187090     0.045730
#                Excited State    S3:     -0.115423     0.276467    -0.258436
#                Excited State    S4:      0.138835    -0.667746     0.551461
#                Excited State    S5:     -0.795852    -0.318666    -0.185543
#
#                Electric Transition Dipole Moments (dipole velocity, a.u.)
#                ----------------------------------------------------------
#                                                 X            Y            Z
#                Excited State    S1:      0.333083    -0.459112    -0.639805
#                Excited State    S2:      0.364640     0.197415     0.048260
#                Excited State    S3:     -0.121784     0.291713    -0.272688
#                Excited State    S4:      0.149628    -0.719695     0.594365
#                Excited State    S5:     -0.857768    -0.343463    -0.199984
#
#                Magnetic Transition Dipole Moments (a.u.)
#                -----------------------------------------
#                                                 X            Y            Z
#                Excited State    S1:     -0.200578     0.054926    -0.143835
#                Excited State    S2:     -0.008558     0.062377    -0.190406
#                Excited State    S3:     -0.196274    -0.015319     0.071283
#                Excited State    S4:      0.108222    -0.170583    -0.233798
#                Excited State    S5:     -0.143217     0.204642     0.262802
#
#                One-Photon Absorption
#                ---------------------
#                Excited State    S1:      0.26292119 a.u.      7.15445 eV    Osc.Str.    0.0383
#                Excited State    S2:      0.34304458 a.u.      9.33472 eV    Osc.Str.    0.0358
#                Excited State    S3:      0.34304975 a.u.      9.33486 eV    Osc.Str.    0.0358
#                Excited State    S4:      0.44766921 a.u.     12.18170 eV    Osc.Str.    0.2296
#                Excited State    S5:      0.44767591 a.u.     12.18188 eV    Osc.Str.    0.2296
#
#                Electronic Circular Dichroism
#                -----------------------------
#                Excited State    S1:     Rot.Str.     -0.000000 a.u.    -0.0000 [10**(-40) cgs]
#                Excited State    S2:     Rot.Str.      0.000004 a.u.     0.0021 [10**(-40) cgs]
#                Excited State    S3:     Rot.Str.     -0.000004 a.u.    -0.0018 [10**(-40) cgs]
#                Excited State    S4:     Rot.Str.     -0.000001 a.u.    -0.0004 [10**(-40) cgs]
#                Excited State    S5:     Rot.Str.      0.000004 a.u.     0.0017 [10**(-40) cgs]
#
#                Character of excitations:
#
#                Excited state 1
#                ---------------
#                HOMO     -> LUMO         0.9989
#
#                Excited state 2
#                ---------------
#                HOMO     -> LUMO+1       0.9752
#                HOMO     -> LUMO+2       0.2168
#
#                Excited state 3
#                ---------------
#                HOMO     -> LUMO+2       0.9752
#                HOMO     -> LUMO+1      -0.2168
#
#                Excited state 4
#                ---------------
#                HOMO-1   -> LUMO        -0.9813
#
#                Excited state 5
#                ---------------
#                HOMO-2   -> LUMO        -0.9813

# %% [markdown]
# ## 3.2 Implicit solvation — SMD
#
# **SMD** (Solvation Model based on Density) adds cavitation, dispersion, and short-range solute–solvent terms on top of a CPCM electrostatics calculation. It gives more accurate solvation free energies across diverse solvents.

# %%
molecule_meoh = vlx.Molecule.read_name('methanol')
basis_meoh    = vlx.MolecularBasis.read(molecule_meoh, 'def2-svp')

scf_smd = vlx.ScfRestrictedDriver()
scf_smd.solvation_model = 'smd'
scf_smd.smd_solvent     = 'water'
scf_results_smd = scf_smd.compute(molecule_meoh, basis_meoh)

print('SMD energy (water):', scf_results_smd['scf_energy'], 'Hartree')
# Out:
# Reading methanol from PubChem...
#
# Reference: S. Kim, J. Chen, T. Cheng, A. Gindulyte, J. He, S. He, Q. Li, B. A. Shoemaker, P. A. Thiessen, B. Yu, L. Zaslavsky, J. Zhang, E. E. Bolton, Nucleic Acids Res., 2025, 53, D1516-D1525.
#
# Please double-check the compound since names may refer to more than one record.
#
#
#                                             Self Consistent Field Driver Setup
#                                            ====================================
#
#                    Wave Function Model             : Spin-Restricted Hartree-Fock
#                    Initial Guess Model             : Superposition of Atomic Densities
#                    Convergence Accelerator         : Two Level Direct Inversion of Iterative Subspace
#                    Max. Number of Iterations       : 50
#                    Max. Number of Error Vectors    : 10
#                    Convergence Threshold           : 1.0e-06
#                    ERI Screening Threshold         : 1.0e-12
#                    Linear Dependence Threshold     : 1.0e-06
#                    Solvation Model                 : SMD
#                    C-PCM Dielectric Constant       : 78.355
#                    C-PCM Points per Hydrogen Sphere: 110
#                    C-PCM Points per non-H Sphere   : 194
#
# * Info * Using the SMD solvation model.
#
#          A. V. Marenich, C. J. Cramer, D. G. Truhlar, J. Phys. Chem. B, 2009, 113, 6378-6396.
#
# * Info * Using C-PCM with the ISWIG discretization method.
#
#          A. W. Lange, J. M. Herbert, J. Chem. Phys. 2010, 133, 244111.
#
# * Info * Starting Reduced Basis SCF calculation...
# * Info * ...done. SCF energy in reduced basis set: -114.899297661362 a.u. Time: 0.68 sec.
#
#
#                Iter. | Hartree-Fock Energy | Energy Change | Gradient Norm | Max. Gradient | Density Change
#                --------------------------------------------------------------------------------------------
#                   1      -114.957939918757    0.0000000000      0.11597939      0.01014388      0.00000000
#                   2      -114.959389655221   -0.0014497365      0.02444651      0.00199992      0.03903424
#                   3      -114.959454964294   -0.0000653091      0.00521241      0.00062702      0.00846620
#                   4      -114.959460116306   -0.0000051520      0.00163401      0.00012518      0.00259734
#                   5      -114.959460729194   -0.0000006129      0.00025751      0.00002703      0.00130473
#                   6      -114.959460752076   -0.0000000229      0.00006432      0.00000570      0.00025755
#                   7      -114.959460753077   -0.0000000010      0.00002998      0.00000263      0.00003863
#                   8      -114.959460753258   -0.0000000002      0.00000485      0.00000044      0.00001560
#                   9      -114.959460753334   -0.0000000001      0.00000099      0.00000009      0.00000350
#
#                *** SCF converged in 9 iterations. Time: 1.16 sec.
#
#                Spin-Restricted Hartree-Fock:
#                -----------------------------
#                Total Energy                       :     -114.9594607533 a.u.
#                Electronic Energy                  :     -155.2909190821 a.u.
#                SMD Solvation Energy               :       -0.0104418978 a.u
#                ... ENP contribution               :       -0.0144436420 a.u.
#                ... CDS contribution               :        0.0040017442 a.u.
#                Nuclear Repulsion Energy           :       40.3419002266 a.u.
#                ------------------------------------
#                Gradient Norm                      :        0.0000009872 a.u.
#
#
#                Ground State Information
#                ------------------------
#                Charge of Molecule            :  0.0
#                Multiplicity (2S+1)           :  1
#                Magnetic Quantum Number (M_S) :  0.0
#
# SMD energy (water): -114.95946075333421 Hartree

# %% [markdown]
# ## 3.3 Explicit solvation — Non Polarizable Embedding (PE)
#
# In the **non polarizable embedding** model, explicit solvent molecules are represented by:
# - **Site charges** — reproduce the electrostatic potential
#
# The potential file (`*.pot`) contains the environemnt. VeloxChem reads this file and incorporates the environment into the SCF and linear-response equations.
#
# Below we prepare the potential file for a water molecule surrounded by four explicit water molecules.

# %%
import py3Dmol

viewer = py3Dmol.view(width=350, height=300, linked=False)

h2o_xyz = """3
water (QM)
O        0.0000000000      0.0000000000      0.0000000000
H        0.6891400000      0.8324710000      0.0000000000
H        0.7224340000     -0.8726890000      0.0000000000
"""

solvent_xyz = """12
solvent shell (MM)
O        1.0991810000      2.2167050000      0.2791250000
H        2.2673500000      2.2529740000      0.6013580000
H        0.9984050000      2.8080510000     -0.5840690000
O       -0.8223690000      0.2141140000     -2.3767710000
H       -1.5990410000      0.8408210000     -2.6698860000
H       -0.4683410000      0.4151750000     -1.5365150000
O        1.7377440000     -2.0168380000     -0.4861090000
H        2.0753880000     -2.2446490000     -1.3654140000
H        1.6636970000     -2.7516570000      0.0543720000
O       -1.0758700000     -0.2692330000      2.5139440000
H       -0.5822670000     -0.1887880000      1.5058600000
H       -1.1632420000      0.7082890000      2.8568430000
"""

viewer.addModel(h2o_xyz,     'xyz')  # model 0: QM water
viewer.addModel(solvent_xyz, 'xyz')  # model 1: MM shell
viewer.setStyle({}, {})
viewer.addStyle({'model': 0}, {'stick': {'radius': 0.25, 'colorscheme': 'Jmol'}})
viewer.addStyle({'model': 1}, {'stick': {'radius': 0.45, 'color': '#9bbcff'}})
viewer.setViewStyle({'style': 'outline', 'color': 'black', 'width': 0.1})
viewer.rotate(45, 'x')
viewer.zoomTo({'model': 0})
viewer.show()
# Out:
# <div id="3dmolviewer_17791770849848907"  style="position: relative; width: 350px; height: 300px;">
#         <p id="3dmolwarning_17791770849848907" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdn.jsdelivr.net/npm/3dmol@2.5.4/build/3Dmol-min.js');
# }
#
# var viewer_17791770849848907 = null;
# var warn = document.getElementById("3dmolwarning_17791770849848907");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17791770849848907 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17791770849848907"),{backgroundColor:"white"});
# viewer_17791770849848907.zoomTo();
# 	viewer_17791770849848907.addModel("3\nwater (QM)\nO        0.0000000000      0.0000000000      0.0000000000\nH        0.6891400000      0.8324710000      0.0000000000\nH        0.7224340000     -0.8726890000      0.0000000000\n","xyz");
# 	viewer_17791770849848907.addModel("12\nsolvent shell (MM)\nO        1.0991810000      2.2167050000      0.2791250000\nH        2.2673500000      2.2529740000      0.6013580000\nH        0.9984050000      2.8080510000     -0.5840690000\nO       -0.8223690000      0.2141140000     -2.3767710000\nH       -1.5990410000      0.8408210000     -2.6698860000\nH       -0.4683410000      0.4151750000     -1.5365150000\nO        1.7377440000     -2.0168380000     -0.4861090000\nH        2.0753880000     -2.2446490000     -1.3654140000\nH        1.6636970000     -2.7516570000      0.0543720000\nO       -1.0758700000     -0.2692330000      2.5139440000\nH       -0.5822670000     -0.1887880000      1.5058600000\nH       -1.1632420000      0.7082890000      2.8568430000\n","xyz");
# 	viewer_17791770849848907.setStyle({},{});
# 	viewer_17791770849848907.addStyle({"model": 0},{"stick": {"radius": 0.25, "colorscheme": "Jmol"}});
# 	viewer_17791770849848907.addStyle({"model": 1},{"stick": {"radius": 0.45, "color": "#9bbcff"}});
# 	viewer_17791770849848907.setViewStyle({"style": "outline", "color": "black", "width": 0.1});
# 	viewer_17791770849848907.rotate(45,"x");
# 	viewer_17791770849848907.zoomTo({"model": 0});
# viewer_17791770849848907.render();
# });
# </script>

# %%
import veloxchem as vlx
# SCF with polarizable embedding
solute_xyz = """3
water
O        0.0000000000      0.0000000000      0.0000000000
H        0.6891400000      0.8324710000      0.0000000000
H        0.7224340000     -0.8726890000      0.0000000000
"""

# create a veloxchem *.pot file
with open("embedding.pot", "w") as pot_file:
    pot_file.write("""12
xyz
O        1.0991810000      2.2167050000      0.2791250000    -0.834
H        2.2673500000      2.2529740000      0.6013580000     0.417
H        0.9984050000      2.8080510000     -0.5840690000     0.417
O       -0.8223690000      0.2141140000     -2.3767710000    -0.834
H       -1.5990410000      0.8408210000     -2.6698860000     0.417
H       -0.4683410000      0.4151750000     -1.5365150000     0.417
O        1.7377440000     -2.0168380000     -0.4861090000    -0.834
H        2.0753880000     -2.2446490000     -1.3654140000     0.417
H        1.6636970000     -2.7516570000      0.0543720000     0.417
O       -1.0758700000     -0.2692330000      2.5139440000    -0.834
H       -0.5822670000     -0.1887880000      1.5058600000     0.417
H       -1.1632420000      0.7082890000      2.8568430000     0.417
""")

molecule = vlx.Molecule.read_xyz_string(solute_xyz)
basis = vlx.MolecularBasis.read(molecule, "cc-pvdz")
scf_drv = vlx.ScfRestrictedDriver()
scf_results = scf_drv.compute(molecule, basis)

scf_drv = vlx.ScfRestrictedDriver()
scf_drv.point_charges = "embedding.pot"
scf_env_results = scf_drv.compute(molecule, basis)


print('Gas phase SCF energy:', scf_results['scf_energy'], 'Hartree')
print('PE SCF energy:', scf_env_results['scf_energy'], 'Hartree')
# Out:
#
#                                             Self Consistent Field Driver Setup
#                                            ====================================
#
#                    Wave Function Model             : Spin-Restricted Hartree-Fock
#                    Initial Guess Model             : Superposition of Atomic Densities
#                    Convergence Accelerator         : Two Level Direct Inversion of Iterative Subspace
#                    Max. Number of Iterations       : 50
#                    Max. Number of Error Vectors    : 10
#                    Convergence Threshold           : 1.0e-06
#                    ERI Screening Threshold         : 1.0e-12
#                    Linear Dependence Threshold     : 1.0e-06
#
# * Info * Starting Reduced Basis SCF calculation...
# * Info * ...done. SCF energy in reduced basis set: -75.952562854356 a.u. Time: 0.02 sec.
#
#
#                Iter. | Hartree-Fock Energy | Energy Change | Gradient Norm | Max. Gradient | Density Change
#                --------------------------------------------------------------------------------------------
#                   1       -75.986061345341    0.0000000000      0.08352262      0.00923177      0.00000000
#                   2       -75.986879222254   -0.0008178769      0.01737966      0.00239881      0.02184843
#                   3       -75.986922135597   -0.0000429133      0.00378875      0.00049625      0.00452353
#                   4       -75.986924676538   -0.0000025409      0.00235277      0.00036551      0.00146151
#                   5       -75.986925283183   -0.0000006066      0.00024934      0.00004213      0.00055517
#                   6       -75.986925300344   -0.0000000172      0.00003713      0.00000572      0.00014619
#                   7       -75.986925300687   -0.0000000003      0.00000222      0.00000022      0.00002019
#                   8       -75.986925300688   -0.0000000000      0.00000057      0.00000008      0.00000108
#
#                *** SCF converged in 8 iterations. Time: 0.07 sec.
#
#                Spin-Restricted Hartree-Fock:
#                -----------------------------
#                Total Energy                       :      -75.9869253007 a.u.
#                Electronic Energy                  :      -83.9512283254 a.u.
#                Nuclear Repulsion Energy           :        7.9643030247 a.u.
#                ------------------------------------
#                Gradient Norm                      :        0.0000005671 a.u.
#
#
#                Ground State Information
#                ------------------------
#                Charge of Molecule            :  0.0
#                Multiplicity (2S+1)           :  1
#                Magnetic Quantum Number (M_S) :  0.0
#
#
#                                             Self Consistent Field Driver Setup
#                                            ====================================
#
#                    Wave Function Model             : Spin-Restricted Hartree-Fock
#                    Initial Guess Model             : Superposition of Atomic Densities
#                    Convergence Accelerator         : Two Level Direct Inversion of Iterative Subspace
#                    Max. Number of Iterations       : 50
#                    Max. Number of Error Vectors    : 10
#                    Convergence Threshold           : 1.0e-06
#                    ERI Screening Threshold         : 1.0e-12
#                    Linear Dependence Threshold     : 1.0e-06
#
# * Info * Preparing for QM/MM calculation.
#
# * Info * Reading point charges: embedding.pot
#
# * Info * Starting Reduced Basis SCF calculation...
# * Info * ...done. SCF energy in reduced basis set: -76.038022416053 a.u. Time: 0.02 sec.
#
#
#                Iter. | Hartree-Fock Energy | Energy Change | Gradient Norm | Max. Gradient | Density Change
#                --------------------------------------------------------------------------------------------
#                   1       -76.052903070995    0.0000000000      0.12343120      0.01638902      0.00000000
#                   2       -76.054707048951   -0.0018039780      0.04476471      0.00712497      0.03402922
#                   3       -76.054991507470   -0.0002844585      0.01884805      0.00306447      0.01302736
#                   4       -76.055039027496   -0.0000475200      0.00355992      0.00050547      0.00517011
#                   5       -76.055042718465   -0.0000036910      0.00033383      0.00004945      0.00217478
#                   6       -76.055042751501   -0.0000000330      0.00009303      0.00001350      0.00017403
#                   7       -76.055042754888   -0.0000000034      0.00002005      0.00000278      0.00006372
#                   8       -76.055042755043   -0.0000000002      0.00000294      0.00000042      0.00001473
#                   9       -76.055042755046   -0.0000000000      0.00000062      0.00000008      0.00000205
#
#                *** SCF converged in 9 iterations. Time: 0.07 sec.
#
#                Spin-Restricted Hartree-Fock:
#                -----------------------------
#                Total Energy                       :      -76.0550427550 a.u.
#                Electronic Energy                  :      -83.9338862181 a.u.
#                Nuclear Repulsion Energy           :        7.9643030247 a.u.
#                Nuclei-Point Charges Energy        :       -0.0854595617 a.u.
#                ------------------------------------
#                Gradient Norm                      :        0.0000006181 a.u.
#
#
#                Ground State Information
#                ------------------------
#                Charge of Molecule            :  0.0
#                Multiplicity (2S+1)           :  1
#                Magnetic Quantum Number (M_S) :  0.0
#
# SCF energy: -75.98692530068811 Hartree
# PE energy: -76.05504275504562 Hartree

# %% [markdown]
# ## Summary
#
# | Topic | Key tool | What we learned |
# |-------|----------|-----------------|
# | Systematic conformer search | `vlx.ConformerGenerator` | Grid search + MMFF minimisation; RESP charges and implicit solvent improve results |
# | MD-based conformer sampling | `vlx.OpenMMDynamics` | High-T MD with deduplication scales to large flexible molecules |
# | Implicit solvation | CPCM, SMD | Cheap continuum model for SCF and spectra |
# | Explicit QM/MM | Non-PE | Environment represented as PC — physically more accurate|
